# %% [markdown]
# # 크롤링

# %% [markdown]
# ### 라이브러리
#     정적인 페이지 = BeautifulSoup
#     동적인 페이지 = Selenium

# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\user\miniconda3\envs\py\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\miniconda3\envs\py\lib\site-packages (from BeautifulSoup4) (2.3.2.post1)

# %%
from bs4 import BeautifulSoup

# %%
html = '<h1 id="title">머신러닝</h1><div class="top">'
html += '<ul class="menu"><li><a href=https://accounts.kakao.com/login/?'
html += 'continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252F'
html += 'www.daum.net class="login">로그인 </a></li></ul><ul class="brand"><li>'
html += '<a href="https://news.daum.net//>다음뉴스<li><a href="http://www.daum.co.kr/academy/">다음</a></li></ul></div>'

# %%
html
# Out:
# '<h1 id="title">머신러닝</h1><div class="top"><ul class="menu"><li><a href=https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net class="login">로그인 </a></li></ul><ul class="brand"><li><a href="https://news.daum.net//>다음뉴스<li><a href="http://www.daum.co.kr/academy/">다음</a></li></ul></div>'

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <h1 id="title">
#  머신러닝
# </h1>
# <div class="top">
#  <ul class="menu">
#   <li>
#    <a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">
#     로그인
#    </a>
#   </li>
#  </ul>
#  <ul class="brand">
#   <li>
#    <a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">
#     다음
#    </a>
#   </li>
#  </ul>
# </div>

# %%
soup.h1
# Out:
# <h1 id="title">머신러닝</h1>

# %%
tag_h1 = soup.h1
tag_h1
# Out:
# <h1 id="title">머신러닝</h1>

# %%
tag_div = soup.div
tag_div
# Out:
# <div class="top"><ul class="menu"><li><a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a></li></ul><ul class="brand"><li><a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">다음</a></li></ul></div>

# %%
tag_ul = soup.li
tag_ul
# Out:
# <li><a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a></li>

# %%
tag_a = soup.a
tag_a
# Out:
# <a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a>

# %% [markdown]
# # 지정된 태그 모두 파싱

# %%
tag_ul_all = soup.find_all('ul')
tag_ul_all
# Out:
# [<ul class="menu"><li><a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a></li></ul>,
#  <ul class="brand"><li><a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">다음</a></li></ul>]

# %%
tag_ul_all[1]
# Out:
# <ul class="brand"><li><a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">다음</a></li></ul>

# %%
tag_li_all = soup.find_all('li')
tag_li_all
# Out:
# [<li><a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a></li>,
#  <li><a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">다음</a></li>]

# %%
tag_a_all = soup.find_all('a')
tag_a_all
# Out:
# [<a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a>,
#  <a "="" academy="" href="https://news.daum.net//&gt;다음뉴스&lt;li&gt;&lt;a href=" http:="" www.daum.co.kr="">다음</a>]

# %% [markdown]
# # 속성을 이용한 파싱

# %%
tag_a.attrs
# Out:
# {'href': 'https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net',
#  'class': ['login']}

# %%
tag_a['href']
# Out:
# 'https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net'

# %%
tag_a.attrs['href']
# Out:
# 'https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net'

# %%
tag_a['class'], tag_a.attrs['class']
# Out:
# (['login'], ['login'])

# %%
title = soup.find(id='title')
title
# Out:
# <h1 id="title">머신러닝</h1>

# %%
title.string
# Out:
# '머신러닝'

# %%
li_list = soup.select('div>ul.menu>li')
li_list
# Out:
# [<li><a class="login" href="https://accounts.kakao.com/login/?continue=https%3A%2F%2Flogins.daum.net%2Faccounts%2Fksso.do%3Frescue%3Dtrue%26url%3Dhttps%253A%252F%252Fwww.daum.net">로그인 </a></li>]

# %% [markdown]
# ### 정리
#     attrs : 속성과 값을 dic 형태로 반환
#     find() : 속성을 이용해서 특정 태그 파싱
#     select() : 지정한 태그를 모두 파싱해서 리스트 구성 태그#id 속성값 태그.class 속성값

# %% [markdown]
# ### 웹사이트가 크롤링을 허용하는지 확인
#     크롤링할 주소/robots.txt

# %%
import urllib.request
result = []

# %%
def getStoreFromPage(page):
    url = f'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo={page}&sido=&gugun=&store='
    html = urllib.request.urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    tag_tbody = soup.find('tbody')
    tag_tbody_trs = tag_tbody.find_all('tr')
    for s in tag_tbody_trs:
        tag_td = s.find_all('td')
        result.append([tag_td[0].string] + [tag_td[1].string] + [tag_td[2].string] + [tag_td[3].string] + [tag_td[5].string])

# %%
result = []
for page in range(1, 53+1):
    getStoreFromPage(page)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\envs\py\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\envs\py\lib\site-packages (from tqdm) (0.4.5)

# %%
from tqdm import tqdm

# %%
result = []
for page in tqdm(range(1, 53+1)):
    getStoreFromPage(page)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 53/53 [00:15<00:00,  3.52it/s]

# %%
result
# Out:
# [['충남 천안시 동남구',
#   '순천향대학교 천안병원 외래센터점',
#   '영업중',
#   '충청남도 천안시 동남구 순천향6길 31 (봉명동, 순천향대학교천안병원) 외래센터 2층',
#   '.'],
#  ['충남 천안시 동남구',
#   '순천향대학교 천안병원 본관점',
#   '영업중',
#   '충청남도 천안시 동남구 순천향6길 31 (봉명동, 순천향대학교천안병원) 본관 1층',
#   '.'],
#  ['충남 공주시', '(천)이인휴게소점', '영업중', '충청남도 공주시 이인면 논산천안고속도로 32 (이인상행휴게소) .', '.'],
#  ['충남 공주시', '(논)탄천휴게소2호점', '영업중', '충청남도 공주시 탄천면 논산천안고속도로 27 (탄천하행휴게소) .', '.'],
#  ['서울 강남구',
#   '강남우리라운지점',
#   '영업중',
#   '서울특별시 강남구 테헤란로 301 역삼동 701-02 삼정빌딩 1층',
#   '02-566-1002'],
#  ['경기 수원시', '수원영통점', '영업중', '경기도 수원시 영통구 청명남로 10 영통동 1000-1', '031-202-3356'],
#  ['경기 고양시 덕양구',
#   '원흥역점',
#   '영업중',
#   '경기 고양시 덕양구 권율대로 690 201동 108호~111호',
#   '031.967.0302'],
#  ['서울 용산구', '이태원역점', '영업중', '서울특별시 용산구 이태원로 180 2층~3층', '02-749-8752'],
#  ['서울 양천구', '오목교역점', '영업중', '서울특별시 양천구 오목로 344 (목동, 청학빌딩) 1층', '02-2062-8405'],
#  ['대구 서구',
#   '롯데시네마프리미엄만경관점',
#   '영업중',
#   '대구 중구 국채보상로 547 MMC 만경관 4층 .',
#   '070-7717-2192'],
#  ['전남 순천시', '순천신대점', '영업중', '전라남도 순천시 해룡면 향매로 67 신대리 1978', '061-723-5185'],
#  ['서울 금천구', '시흥사거리점', '영업중', '서울특별시 금천구 시흥대로 225 시흥동 994-9', '02-804-9226'],
#  ['전북 전주시 완산구',
#   '전주효천점',
#   '영업중',
#   '전라북도 전주시 완산구 쑥고개로 351, 1층 101호~102호 효자동2가 1326-4',
#   '063-224-5777'],
#  ['제주 제주시', '제주도두해안DT점', '영업중', '제주특별자치도 제주시 도두일동 1686 .', '064-745-7301'],
#  ['부산 북구',
#   '부산화명점',
#   '영업중',
#   '부산광역시 북구 금곡대로285번길 13 (화명동, 스포렉스) 스포렉스 106호,107호,108호',
#   '070-8884-1101'],
#  ['서울 서초구',
#   '방배역점',
#   '영업중',
#   '서울특별시 서초구 방배로 107 (방배동, 디엠타워3관) 1층',
#   '02-523-4180'],
#  ['경기 고양시 덕양구',
#   '고양향동점',
#   '영업중',
#   '경기도 고양시 덕양구 향기3로 9, 101호 (향동동) 향동동 536',
#   '02-3158-0031'],
#  ['광주 북구', '광주북구청점', '영업중', '광주광역시 북구 서방로 2 (중흥동) .', '062-511-8002'],
#  ['전북 전주시 완산구',
#   '전주한옥마을점',
#   '영업중',
#   '전라북도 전주시 완산구 은행로 16 (풍남동 1가 53-3) .',
#   '063-288-0801'],
#  ['강원 홍천군', '(상)홍천휴게소R점', '영업중', '강원도 홍천군 화촌면 서울양양고속도로 83 .', '010-4668-2505'],
#  ['부산 부산진구', '부산시민공원점', '영업중', '부산 부산진구 시민공원로 73, 푸드코트피크닉 범전동 200', '.'],
#  ['충남 홍성군', '충남도청점', '영업중', '충청남도 홍성군 홍북읍 신경리 553 .', '041-631-4725'],
#  ['경기 고양시 일산동구',
#   '성남모란역점',
#   '영업중',
#   '경기도 성남시 중원구 성남대로1148번길 8 1층, 성남동 3453',
#   '031-758-5953'],
#  ['서울 강남구',
#   '강남역2점',
#   '영업중',
#   '서울특별시 강남구 강남대로 422 (역삼동) 역삼동816,816-7,816-8',
#   '02-568-9056'],
#  ['서울 용산구',
#   '숙대입구점',
#   '영업중',
#   '서울특별시 용산구 청파로 276 (청파동2가) 2층~3층 할리스 ',
#   '02-704-9636'],
#  ['경남 김해시',
#   '김해복음병원점',
#   '영업중',
#   '경상남도 김해시 활천로 44 (삼정동) 할리스 김해복음병원점',
#   '055-723-2053'],
#  ['서울 서대문구',
#   '홍제천점',
#   '영업중',
#   '서울특별시 서대문구 홍제내길 52,1~2층 홍제동 361-49',
#   '02-396-0903'],
#  ['경기 고양시 일산동구',
#   '롯데시네마라페스타점',
#   '영업중',
#   '경기도 고양시 일산동구 무궁화로 32-34 (장항동, 라페스타C) 3층',
#   '070-7733-0384'],
#  ['부산 기장군', '부산일광신도시점', '영업중', '부산광역시 기장군 일광읍 해빛6로 43-20 삼성리 840-12', '.'],
#  ['경기 이천시', '이천마장점', '영업중', '경기도 이천시 마장면 오천로 65 오천리 56-55', '070-4647-0081'],
#  ['대전 유성구', '충남대점', '영업중', '대전광역시 유성구 대학로 84 (궁동 482-6) .', '070-7543-1009'],
#  ['서울 광진구',
#   '강변역점',
#   '영업중',
#   '서울 광진구 구의강변로 64, 구의아크로리버 1층 구의동 589-10',
#   '070-7802-0303'],
#  ['서울 종로구', '종각역점', '영업중', '서울특별시 종로구 종로 60-1 종로2가 102-3', '02-736-3399'],
#  ['부산 사하구',
#   '부산아트몰링영풍문고점',
#   '영업중',
#   '부산광역시 사하구 낙동남로 1413 (하단동, 아트몰링) 13층',
#   '051-201-0621'],
#  ['경기 광명시',
#   '광명GIDC점',
#   '영업중',
#   '경기도 광명시 일직로 43 일직동 514 지하2층 G249, G250호',
#   '02-6914-6550'],
#  ['경기 이천시', '이천점', '영업중', '경기도 이천시 어재연로 35 (창전동) 1~3층 할리스', '031-635-6655'],
#  ['경기 하남시',
#   '미사가로수길점',
#   '영업중',
#   '경기도 하남시 미사강변한강로 295 (망월동, 하남미사롯데캐슬헤븐시티Ⅱ) .',
#   '031-699-8674'],
#  ['경기 시흥시',
#   '시흥능곡점',
#   '영업중',
#   '경기도 시흥시 능곡번영길 25 (능곡동) 능곡동 211-3 (107,108,205,206호)',
#   '070-8806-1314'],
#  ['경기 평택시', '평택칠괴점', '영업중', '경기도 평택시 칠괴길 84 칠괴동 492 1층', '031-665-1770'],
#  ['경기 평택시',
#   '송탄서정점',
#   '영업중',
#   '경기도 평택시 경기대로 1371,102호 서정동 814-1',
#   '031-611-0234'],
#  ['서울 동작구',
#   '장승배기역점',
#   '영업중',
#   '서울특별시 동작구 장승배기로11가길 11, 1층 (상도동, 상도파크자이)',
#   '02-812-9330'],
#  ['경기 하남시',
#   '미사효성해링턴점',
#   '영업중',
#   '경기도 하남시 아리수로 570,1~2층 망월동 미사효성해링턴타워더퍼스',
#   '070-7733-9710'],
#  ['경남 김해시',
#   '김해인제대점',
#   '영업중',
#   '경상남도 김해시 인제로 168 (어방동) 정석빌딩101호',
#   '055-314-8589'],
#  ['전남 순천시',
#   '순천성가롤로병원점',
#   '영업중',
#   '전남 순천시 순광로 221, 순천성가롤로병원 별관 2층 조례동 1742',
#   '061-905-0013'],
#  ['부산 부산진구', '부산동의대점', '영업중', '부산광역시 부산진구 엄광로 176 가야동, 동의대학교', '051-893-6679'],
#  ['경기 군포시',
#   '금정AK프라자점',
#   '영업중',
#   '경기도 군포시 금정동 689 AK프라자 131, 132호',
#   '031-427-8535'],
#  ['울산 남구',
#   '울산삼산로점',
#   '영업중',
#   '울산광역시 남구 삼산로 283 (삼산동, 소망빌딩) 삼산동1525-8,1525-9',
#   '052-275-9004'],
#  ['대구 달성군',
#   '대구세천점',
#   '영업중',
#   '대구광역시 달성군 다사읍 세천로 141 세천리 1581-6',
#   '053-581-5768'],
#  ['부산 동래구', '부산명륜자이점', '영업중', '부산광역시 동래구 동래로 77 (명륜동) 1,2층', '051-554-1001'],
#  ['경기 부천시', '부천송내본점', '영업중', '경기도 부천시 송내대로 73번길 21 (상동) 1층', '032-321-2007'],
#  ['충남 공주시', '동학사점', '영업중', '충남 공주시 반포면 동학사2로 133 1,2층 .', '070-8836-8038'],
#  ['서울 서대문구',
#   '서울명지대점',
#   '영업중',
#   '서울특별시 서대문구 거북골로 41-1 (남가좌동) 1층~2층',
#   '02-304-1110'],
#  ['경기 부천시', '부천순천향병원점', '영업중', '경기도 부천시 조마루로 170(중동) 본관 지하 1층 .', '.'],
#  ['전북 전주시 완산구',
#   '전주시네마점',
#   '영업중',
#   '전라북도 전주시 완산구 전주객사3길 67 (고사동, 전주시네마타운) 1~2층',
#   '063-232-9448'],
#  ['충남 천안시 동남구',
#   '천안신부점',
#   '영업중',
#   '충청남도 천안시 동남구 만남로 26 (신부동, 대영빌딩) 4~5층',
#   '041-566-5085'],
#  ['서울 강서구',
#   '목동삼성쉐르빌점',
#   '영업중',
#   '서울특별시 양천구 목동동로 189 (신정동, 삼성쉐르빌1) 1층 101,102,103호',
#   '02-2652-2030'],
#  ['경기 평택시',
#   '삼성전자평택캠퍼스점',
#   '영업중',
#   '경기도 평택시 삼성로 144 고덕면 여염리 1648',
#   '031-8094-9981'],
#  ['충남 아산시', '천안아산역사점', '영업중', '충청남도 아산시 배방읍 희망로 100 (천안아산역) 3층 맞이방', '.'],
#  ['경기 성남시 분당구',
#   '분당미금점',
#   '영업중',
#   '경기도 성남시 분당구 미금일로90번길 24 (구미동) B1F ~ 1F',
#   '031-713-7739'],
#  ['부산 서구',
#   '부산서구청점',
#   '영업중',
#   '부산광역시 서구 보수대로 9 (충무동1가 3-1) 바른빌딩 1층 104호',
#   '070-4647-1455'],
#  ['대구 북구', '대구연경점', '영업중', '대구광역시 북구 동화천로 229 (연경동) 1층~2층', '053-982-6877'],
#  ['울산 울주군', '울산율리점', '영업중', '울산광역시 울주군 청량읍 율리영해1길 46 1층', '052-221-1030'],
#  ['경남 창원시 마산회원구',
#   '마산호계점',
#   '영업중',
#   '경상남도 창원시 마산회원구 내서읍 광려천동로 28 (내서신화하니엘더시티) 상가 1~2층',
#   '.'],
#  ['경남 창원시 진해구',
#   '진해경화점',
#   '영업중',
#   '경상남도 창원시 진해구 조천북로 76 (경화동) .',
#   '055-547-9906'],
#  ['서울 동작구', '중앙대점', '영업중', '서울특별시 동작구 흑석로 77 (흑석동) 할리스 1~4층', '02-3280-3280'],
#  ['경기 고양시 덕양구', '고양신원점', '영업중', '경기도 고양시 덕양구 권율대로 896-19 .', '02-381-7666'],
#  ['경기 부천시', '부천심곡점', '영업중', '경기도 부천시 장말로 376  심곡동 355-1', '.'],
#  ['제주 제주시',
#   '제주연북로점',
#   '영업중',
#   '제주특별자치도 제주시  오남로 166 (오라이동 1550-11)',
#   '070-4123-5111'],
#  ['전북 군산시', '군산선유도점', '영업중', '전라북도 군산시 옥도면 선유도리 213-3 .', '063-464-9314'],
#  ['경기 고양시 덕양구',
#   '고양삼송점',
#   '영업중',
#   '경기도 고양시 덕양구 삼송로 222 (삼송동, 삼송역현대헤리엇) 1층 할리스',
#   '070-7643-6611'],
#  ['서울 종로구',
#   '독립문역점',
#   '영업중',
#   '서울특별시 종로구 통일로 230 (무악동, 경희궁롯데캐슬) 상가동  1층',
#   '010-2594-7308'],
#  ['전북 익산시', '익산모현점', '영업중', '전라북도 익산시 선화로3길 16-10 1층', '063-842-8420'],
#  ['경기 고양시 일산서구',
#   '일산문촌마을점',
#   '영업중',
#   '경기도 고양시 일산서구 중앙로 1493 ,상가동 1층 1001-1, 1001-2',
#   '070-7797-3247'],
#  ['서울 종로구', '성균관대점', '영업중', '서울특별시 종로구 성균관로 6 (명륜2가 204) 1~4층', '02-743-8526'],
#  ['대전 서구',
#   '대전건양대병원점',
#   '영업중',
#   '대전광역시 서구 관저동로 158 (관저동, 건양대학교병원) 신관 지하1층',
#   '042-543-3138'],
#  ['대전 유성구', '대전유성온천점', '영업중', '대전 유성구 온천로 45  1,2층', '042-825-2023'],
#  ['경기 시흥시',
#   '스틸랜드점',
#   '영업중',
#   '경기도 시흥시 오이도로 21 (정왕동, STEELLAND) 1층',
#   '070-8802-8041'],
#  ['경남 거제시', '거제휴게소점', '영업중', '경상남도 거제시 장목면 거가대로 1068 .', '055-736-2200'],
#  ['부산 강서구', '가덕휴게소점', '영업중', '부산광역시 강서구 거가대로 2571 (천성동) .', '051-715-2200'],
#  ['경기 성남시 분당구',
#   '판교역점',
#   '영업중',
#   '경기도 성남시 분당구 판교역로192번길 12 (삼평동, 판교미래에셋센터) 1층',
#   '031-8061-0778'],
#  ['서울 노원구', '태릉입구역점', '영업중', '서울특별시 노원구 화랑로 453 (공릉동, 그린힐) 1층', '02-976-0078'],
#  ['경남 창원시 마산합포구',
#   '마산저도점',
#   '영업중',
#   '경상남도 창원시 마산합포구 구산면 해양관광로 1872-50 2~3층',
#   '055-243-1052'],
#  ['충북 옥천군', '충북옥천점', '영업중', '충청북도 옥천군 옥천읍 송신길 172 .', '043-731-5560'],
#  ['경기 화성시', '화성조암점', '영업중', '경기도 화성시 우정읍 쌍봉로 76 103호', '031-358-3567'],
#  ['충북 청주시 서원구',
#   '청주성화점',
#   '영업중',
#   '충청북도 청주시 서원구 신성화로 39 (성화동) 1~2층',
#   '043-233-6296'],
#  ['경기 구리시',
#   '모다아울렛구리점',
#   '영업중',
#   '경기도 구리시 경춘북로 230 (갈매동, 모다아울렛) .',
#   '031-514-8194'],
#  ['서울 구로구',
#   '구로디지털점',
#   '영업중',
#   '서울특별시 구로구 디지털로31길 12 1층 105,106호',
#   '070-7576-4842'],
#  ['경기 안성시',
#   '(상)안성맞춤휴게소점',
#   '영업중',
#   '경기도 안성시 서운면 평택제천고속도로 41 (안성맞춤휴게소평택방향) .',
#   '031-673-3822'],
#  ['전남 나주시', '나주빛가람혁신도시점', '영업중', '전라남도 나주시 배멧3길 5-4 (빛가람동) .', '061-334-5466'],
#  ['서울 종로구', '청계천점', '영업중', '서울특별시 종로구  청계천로 81 1,2,3,4층', '02-735-5462'],
#  ['충남 공주시', '(논)탄천휴게소점', '영업중', '충청남도 공주시 탄천면 논산천안고속도로 27 (탄천하행휴게소) .', '.'],
#  ['충남 공주시',
#   '(상)정안알밤휴게소점',
#   '영업중',
#   '충청남도 공주시 정안면 논산천안고속도로 58 (정안상행휴게소) 1층',
#   '010-4551-8103'],
#  ['인천 연수구',
#   '인천대입구역점',
#   '영업중',
#   '인천광역시 연수구 인천타워대로132번길 34 (송도동) 104호,105호',
#   '032-833-2808'],
#  ['경기 남양주시',
#   '남양주진접점',
#   '영업중',
#   '경기도 남양주시 진접읍 해밀예당1로 8-12 가동 1~2층',
#   '031-523-3237'],
#  ['서울 송파구',
#   '방이역점',
#   '영업중',
#   '서울특별시 송파구 양재대로72길 5 (오금동, 올림픽파크센트레빌) 1층',
#   '02-403-0338'],
#  ['서울 강남구',
#   '청담삼성로점',
#   '영업중',
#   '서울특별시 강남구 삼성로119길 8 (삼성동, 강남대학교청담카이로스빌딩) 1층',
#   '02-541-7755'],
#  ['경기 김포시',
#   '김포운양점',
#   '영업중',
#   '경기도 김포시 김포한강11로255번길 15 (운양동, 김포한강이랜드타운힐스) .',
#   '031-986-2260'],
#  ['울산 남구',
#   '울산교보핫트랙스점',
#   '영업중',
#   '울산광역시 남구 화합로 185 (삼산동) 업스퀘어 B1 교보문고내',
#   '052-990-5550'],
#  ['서울 강동구',
#   '고덕그라시움후문점',
#   '영업중',
#   '서울특별시 강동구 동남로82길 77-1 (고덕동) 2층~4층',
#   '02-2088-0831'],
#  ['강원 속초시', '속초센텀마크점', '영업중', '강원도 속초시 중앙로121번길 28 (금호동) 1층', '033-638-8700'],
#  ['세종 세종시', '세종가람DT점', '영업중', '세종특별자치시 금송로 589 (가람동) .', '044-865-8882'],
#  ['서울 중구',
#   '덕수궁점',
#   '영업중',
#   '서울특별시 중구  세종대로 91 (태평로2가) 1~2층 할리스',
#   '02-6365-0143'],
#  ['경기 김포시',
#   '김포디원시티점',
#   '영업중',
#   '경기도 김포시 김포한강10로133번길 127 (구래동) 할리스커피',
#   '031-8035-1750'],
#  ['대구 동구', '대구봉무공원점', '영업중', '대구광역시 동구 단산길 4 (봉무동) 1~2층', '053-984-3001'],
#  ['서울 영등포구',
#   '보라매역점',
#   '영업중',
#   '서울특별시 영등포구 여의대방로 145 (신길동, 세인트빌딩) .',
#   '02-845-1097'],
#  ['충북 청주시 서원구',
#   '청주산남DT점',
#   '영업중',
#   '충청북도 청주시 서원구 1순환로 892,1,2층(산남동)',
#   '043-287-5731'],
#  ['충북 청주시 흥덕구',
#   '청주강서점',
#   '영업중',
#   '충청북도 청주시 흥덕구 서현동로 8 (가경동, 하나빌딩) .',
#   '043-263-8585'],
#  ['울산 울주군',
#   '(함)울주휴게소점',
#   '영업중',
#   '울산광역시 울주군 삼동면 보은리 산193-1 외 .',
#   '052-933-5243'],
#  ['경기 평택시', '평택이충DT점', '영업중', '경기도 평택시 추담로 30 A동 1~2층 (이충동)', '031-667-7034'],
#  ['경기 평택시',
#   '평택지산점',
#   '영업중',
#   '경기도 평택시 지산로 10, 1층 지산동 808-4, 101,102호',
#   '031-8029-9005'],
#  ['서울 강북구',
#   '미아역점',
#   '영업중',
#   '서울특별시 강북구 도봉로 203, 1-2층 미아동 209-2',
#   '070-7799-7374'],
#  ['경북 성주군', '성주성밖숲점', '영업중', '경상북도 성주군 성주읍 성밖숲길 7 .', '054-933-2222'],
#  ['강원 속초시',
#   '속초영랑해변점',
#   '영업중',
#   '강원도 속초시 영랑해안길 205 (영랑동 148-172) 할리스',
#   '033-637-0164'],
#  ['울산 남구',
#   '울산달동DT점',
#   '영업중',
#   '울산광역시 남구 번영로 82 (달동 1297-1) 할리스',
#   '052-275-3022'],
#  ['인천 연수구', '송도학원가점', '영업중', '인천광역시 연수구 신송로 168 송도동 20-13', '.'],
#  ['인천 서구', '인천당하점', '영업중', '인천광역시 서구 서곶로 788 (당하동, 홀리랜드) 1층', '032-561-1578'],
#  ['경기 시흥시',
#   '시흥은계점',
#   '영업중',
#   '경기도 시흥시 은계번영길 13 (은행동, 아리테타워) 107,108,203~205호',
#   '031-520-8147'],
#  ['서울 관악구', '신림역점', '영업중', '서울특별시 관악구 신림로 313 (신림동) 2층', '02-877-5596'],
#  ['대구 수성구',
#   '대구수성네거리점',
#   '영업중',
#   '대구광역시 수성구 들안로 326 1,2층 수성동3가 254-2',
#   '053-743-8700'],
#  ['인천 서구',
#   '인천서구청점',
#   '영업중',
#   '인천광역시 서구 서곶로301번길 7-1 (심곡동, 세광빌딩) .',
#   '032-569-1235'],
#  ['부산 수영구',
#   '부산광안리점',
#   '영업중',
#   '부산광역시 수영구 광안해변로 175 (광안동, 광안에이파크오션) 1~2층',
#   '051-757-9433'],
#  ['부산 사상구',
#   '부산사상광장점',
#   '영업중',
#   '부산광역시 사상구 광장로 22 (괘법동) 2층 사상구 괘법동 565-2',
#   '051-322-4117'],
#  ['경기 이천시', '이천갈산점', '영업중', '경기도 이천시 향교로 161 (갈산동) 1층 .', '031-636-1791'],
#  ['충북 청주시 상당구',
#   '청주동남점',
#   '영업중',
#   '충청북도 청주시 상당구 중고개로141번길 13-16 (용암동) 101,102,103호 .',
#   '043-293-3030'],
#  ['서울 동작구',
#   '대방역점',
#   '영업중',
#   '서울특별시 동작구 알마타길 6 (대방동, 파밀리에 하늘마루) 101호, 102호 .',
#   '02-825-6369'],
#  ['경기 부천시',
#   '부천옥길점',
#   '영업중',
#   '경기도 부천시 양지로 205, 1~2층 옥길동 793-2, 부천옥길 서영아너시티2',
#   '070-4129-4130'],
#  ['경기 남양주시',
#   '다산진건점',
#   '영업중',
#   '경기도 남양주시 다산중앙로20번길 10-44 (다산동) 1층  .',
#   '070-7808-1221'],
#  ['인천 부평구',
#   '2001아울렛부평점',
#   '영업중',
#   '인천광역시 부평구 경원대로 1277 (산곡동, 2001아울렛부평점) A동 1층',
#   '032-525-1002'],
#  ['울산 남구', '울산삼산점', '영업중', '울산광역시 남구 삼산중로 50 (삼산동) 2층', '052-260-1121'],
#  ['서울 강남구',
#   '강남대로논현점',
#   '영업중',
#   '서울특별시 강남구 강남대로 520 (논현동, 영동빌딩) .',
#   '02-6012-2372'],
#  ['대전 유성구',
#   '대전호텔ICC점',
#   '영업중',
#   '대전광역시 유성구 엑스포로123번길 55 (도룡동) 1층',
#   '042-866-5104'],
#  ['서울 마포구',
#   '홍대거리점',
#   '영업중',
#   '서울특별시 마포구 어울마당로 76-1, 2~4층 (서교동 364-19) 할리스',
#   '02-323-3795'],
#  ['경기 평택시',
#   '(하)평택휴게소1호점',
#   '영업중',
#   '경기도 평택시 청북읍 평택제천고속도로 6 (평택복합휴게시설) .',
#   '031-683-4800'],
#  ['부산 해운대구',
#   '부산센텀시티점',
#   '영업중',
#   '부산광역시 해운대구 센텀2로 24 (우동, 센텀다이아몬드) 1층',
#   '051-755-9100'],
#  ['경기 하남시',
#   '하남미사역점',
#   '영업중',
#   '경기도 하남시 미사강변동로 85 (망월동, 힐스테이트에코미사) 1~2 층 ',
#   '031-8027-6979'],
#  ['경남 창원시 성산구',
#   '창원귀산점',
#   '영업중',
#   '경상남도 창원시 성산구 삼귀로 189 귀곡동 723-21',
#   '055-266-1353'],
#  ['경기 의정부시',
#   '의정부로데오점',
#   '영업중',
#   '경기도 의정부시 행복로 28 (의정부동) 지상 1층~ 4층',
#   '031-848-1674'],
#  ['강원 속초시', '속초엑스포점', '영업중', '강원도 속초시 청초호반로 75 (조양동) 1~3층', '033-638-2123'],
#  ['경기 수원시 영통구',
#   '광교호수점',
#   '영업중',
#   '경기도 수원시 영통구 광교중앙로 180 (하동, 광교효성해링턴타워레이크) 광교효성해링턴타워레이크 B017호~B111호\t',
#   '031-217-8797'],
#  ['경기 안양시 동안구',
#   '범계로데오점',
#   '영업중',
#   '경기도 안양시 동안구 평촌대로223번길 11 (호계동, 성우프라자) 202호, 203호',
#   '031-8033-7562'],
#  ['경기 안산시 단원구',
#   '안산중앙역점',
#   '영업중',
#   '경기도 안산시 단원구 광덕4로 234 (고잔동, 천혜로데오프라자) 107,108호',
#   '031-484-2002'],
#  ['경기 오산시',
#   '오산시청점',
#   '영업중',
#   '경기도 오산시 성호대로 124 (원동, 신협빌딩) 101,102호',
#   '031-378-8778'],
#  ['충남 공주시',
#   '(하)정안알밤휴게소점',
#   '영업중',
#   '충청남도 공주시 정안면 논산천안고속도로 57 (정안하행휴게소) 할리스커피',
#   '.'],
#  ['충북 청주시 흥덕구',
#   '청주NC백화점CGV점',
#   '영업중',
#   '충북 청주시 흥덕구 2순환로 1233  청주NC백화점 8층',
#   '070-4153-5598'],
#  ['서울 노원구',
#   '수락산역점',
#   '영업중',
#   '서울특별시 노원구 동일로239가길 22 (상계동, 한올빌딩) 2층',
#   '02-951-3266'],
#  ['서울 중랑구', '망우점', '영업중', '서울특별시 중랑구 망우로 470 (망우동) 1층', '070-7707-0042'],
#  ['서울 구로구',
#   '구로거리공원점',
#   '영업중',
#   '서울특별시 구로구 구로중앙로28길 52  구로동 109-1',
#   '02-838-7008'],
#  ['강원 양양군', '낙산해수욕장점', '영업중', '강원도 양양군 강현면 해맞이길 18 .', '033-673-0053'],
#  ['경기 안산시 상록구',
#   '안산한대앞점',
#   '영업중',
#   '경기도 안산시 상록구 중보로 31 (이동, 썬프라자) .',
#   '031-419-2131'],
#  ['전북 익산시',
#   '익산부송점',
#   '영업중',
#   '전라북도 익산시 하나로10길 70-1 (부송동, 레스트빌딩) 1층',
#   '063-832-1717'],
#  ['경기 양주시',
#   '양주삼숭DI점',
#   '영업중',
#   '경기도 양주시 부흥로 2239 1,2층 삼숭동 477-1',
#   '031-848-5375'],
#  ['서울 서초구',
#   '교대역점',
#   '영업중',
#   '서울특별시 서초구 반포대로30길 81 (서초동, 웅진타워) 1층 .',
#   '02-521-8944'],
#  ['경기 파주시',
#   '파주운정역점',
#   '영업중',
#   '경기도 파주시 경의로1240번길 37-1  101~3호 201~2호',
#   '031-957-6200'],
#  ['경기 화성시', '제부도점', '영업중', '경기도 화성시 서신면 해안길 434 1,2층', '031-357-6399'],
#  ['경기 남양주시',
#   '다산센트럴점',
#   '영업중',
#   '경기도 남양주시 다산중앙로 105-14 (다산동) 웅신미켈란오피스텔 104,105,106호',
#   '070-8670-1240'],
#  ['강원 인제군', '인제점', '영업중', '강원도 인제군 인제읍 인제로 198 .', '033-461-7767'],
#  ['대전 동구',
#   '가오CGV점',
#   '영업중',
#   '대전광역시 동구 은어송로 72 4층(가오동, 패션아일랜드) .',
#   '042-273-7400'],
#  ['충북 청주시 서원구',
#   '청주분평점',
#   '영업중',
#   '충청북도 청주시 서원구 월평로 4 분평동 1226, 대상탑존빌딩 111호',
#   '043-292-5105'],
#  ['충남 당진시',
#   '당진시청점',
#   '영업중',
#   '충청남도 당진시 시청2로 49-25 (수청동) 로고스타워 1~2층',
#   '070-8808-1040'],
#  ['전북 익산시', '익산영등점', '영업중', '전라북도 익산시 고봉로32길 46-1 (영등동) 1~2층', '063-918-2211'],
#  ['경기 수원시 권선구',
#   '수원SKV1모터스점',
#   '영업중',
#   '경기도 수원시 권선구 평동로79번길 45 (평동) 1층 135호',
#   '031-293-8810'],
#  ['서울 구로구',
#   '구로디지털단지역점',
#   '영업중',
#   '서울특별시 구로구 디지털로32나길 38 (구로동, 서림빌딩) 1층',
#   '02-851-3365'],
#  ['서울 마포구',
#   '공덕경의선숲길점',
#   '영업중',
#   '서울특별시 마포구 백범로28길 22, 일양빌딩 신관 1층 (염리동 164-1)',
#   '.'],
#  ['울산 남구', '울산신정점', '영업중', '울산광역시 남구 동산로 93  신정동 1265-16, 1층', '052-260-0900'],
#  ['경기 안양시 동안구',
#   '평촌점',
#   '영업중',
#   '경기도 안양시 동안구 관평로170번길 43, 훼미리타운 125호 .',
#   '031-385-3400'],
#  ['경남 창원시 진해구',
#   '진해속천점',
#   '영업중',
#   '경상남도 창원시 진해구 태평로 132 (속천동) 2~3층 할리스커피',
#   '055-547-9777'],
#  ['충북 청주시 청원구', '청주율량현대점', '영업중', '충청북도 청주시 청원구 율봉로 150 .', '043-241-0005'],
#  ['대구 달서구', '대구상인점', '영업중', '대구광역시 달서구 상화북로 194 (상인동) 2층', '053-641-9522'],
#  ['경북 칠곡군', '칠곡왜관점', '영업중', '경상북도 칠곡군 석적읍 석적로 178-3 1~2층', '054-977-8255'],
#  ['서울 마포구', '홍대역2번출구점', '영업중', '서울특별시 마포구 동교로 200 1~3층 .', '02-332-8079'],
#  ['서울 송파구',
#   '가락시장역점',
#   '영업중',
#   '서울특별시 송파구 중대로 130 가락동112-2, 원전빌딩 1층\t',
#   '02-3401-5337'],
#  ['경기 화성시',
#   '화성능동DT점',
#   '영업중',
#   '경기 화성시 동탄지성로 215 1,2층 전체호(병점동)',
#   '031-221-7286'],
#  ['인천 남동구', '인천시청점', '영업중', '인천광역시 남동구 남동대로799번길 36 (구월동) .', '032-433-0704'],
#  ['경남 밀양시', '밀양킹콩점', '영업중', '경상남도 밀양시 삼문강변로 272 (삼문동) 2,3층', '055-351-0056'],
#  ['대구 북구',
#   '경북대북문점',
#   '영업중',
#   '대구광역시 북구 대학로 17길 3 (산격동 1393-11) 할리스 B1~3층',
#   '053-951-9990'],
#  ['서울 강남구',
#   '코엑스점',
#   '영업중',
#   '서울특별시 강남구 영동대로 513, 코엑스 지하 1층  C113호 (삼성동 159)  할리스  ',
#   '02-6002-3100'],
#  ['울산 중구', '울산성남점', '영업중', '울산광역시 중구 만남의거리 33, 1F 성남동 256-16', '052-211-4741'],
#  ['경기 양평군', '양평점', '영업중', '경기도 양평군 양평읍 중앙로 90 1층', '031-775-1157'],
#  ['경기 김포시', '김포시청점', '영업중', '경기도 김포시 김포대로 847 중앙프라자 105,204호', '031-996-1388'],
#  ['경기 안산시 단원구',
#   '안산선부점',
#   '영업중',
#   '경기도 안산시 단원구 선부광장1로 56 (선부동) 할리스커피',
#   '031-411-9733\t'],
#  ['경기 고양시 덕양구',
#   '화정역점',
#   '영업중',
#   '경기도 고양시 덕양구 화신로272번길 67  장군빌딩 1층',
#   '070-7514-8707'],
#  ['전북 군산시',
#   '군산새만금산단점',
#   '영업중',
#   '전라북도 군산시 새만금북로 424 (오식도동) 1층 104호',
#   '063-468-4100'],
#  ['경기 남양주시', '다산한강점', '영업중', '경기도 남양주시 다산지금로 163번길 9-12 1층', '031-592-3118'],
#  ['서울 마포구',
#   '상암DDMC점',
#   '영업중',
#   '서울시 마포구 매봉산로 75, DDMC 1층 104호 상암동 1610',
#   '070-4445-2428'],
#  ['경기 고양시 덕양구',
#   '덕양구청점',
#   '영업중',
#   '경기도 고양시 덕양구 화중로104번길 8 (화정동, 장원프라자) 1층 102호',
#   '070-4647-0030'],
#  ['충남 서천군', '(하)서천휴게소점', '영업중', '충청남도 서천군 비인면 서해안고속도로 169 .', '041-952-5757'],
#  ['전북 전주시 덕진구',
#   '전주에코시티세병호점',
#   '영업중',
#   '전라북도 전주시 덕진구 세병로 176 (송천동2가) 1층~2층',
#   '063-255-3000'],
#  ['경기 남양주시',
#   '다산리코빌파크뷰점',
#   '영업중',
#   '경기도 남양주시 다산순환로 220 (다산동) 104 ~107호, 다산동 6020',
#   '031-523-3948'],
#  ['서울 서대문구',
#   '서대문농협생명빌딩점',
#   '영업중',
#   '서울시 서대문구 통일로 87  미근동 257, NH농협생명빌딩 동관 1층',
#   '02-364-7787'],
#  ['충북 청주시 청원구',
#   '(하)오창휴게소점',
#   '영업중',
#   '충청북도 청주시 청원구 오창읍 중부고속도로 21 (오창휴게소통영기점) .',
#   '043-217-1477'],
#  ['충북 청주시 흥덕구',
#   '(하)옥산휴게소점',
#   '영업중',
#   '충청북도 청주시 흥덕구 옥산면 경부고속도로 309 (옥산휴게소부산방향) 옥산휴게소(하행) 할리스커피',
#   '043-260-1053'],
#  ['경기 김포시',
#   '김포지식산업센터점',
#   '영업중',
#   '경기도 김포시 태장로 795번길 145, 아셈호텔 1층 장기동 2011-2',
#   '070-4953-9475'],
#  ['경기 군포시',
#   '군포IT밸리점',
#   '영업중',
#   '경기도 군포시 고산로148번길 17 (당정동, 군포IT밸리) 1층',
#   '031-8086-8211'],
#  ['경남 진주시',
#   '진주혁신도시점',
#   '영업중',
#   '경상남도 진주시 에나로128번길 24 (충무공동) .',
#   '070-7543-2274'],
#  ['전남 광양시', '광양중동점', '영업중', '전라남도 광양시 공영로 92-1 (중동) .', '061-795-6600'],
#  ['대구 달서구', '대구이월드점', '영업중', '대구광역시 달서구 두류공원로 200 (두류동) . ', '053-620-0001'],
#  ['대전 유성구',
#   '대전문지점',
#   '영업중',
#   '대전광역시 유성구 문지로299번길 94-19 (문지동) 1층',
#   '042-861-6947'],
#  ['대구 수성구',
#   '대구범어천로점',
#   '영업중',
#   '대구광역시 수성구 범어천로 200 (범어동, 범어월드메르디앙웨스턴카운티) 102호,201호',
#   '053-759-5779'],
#  ['서울 강서구',
#   '마곡나인스퀘어점',
#   '영업중',
#   '서울특별시 강서구 공항대로 206 (마곡동, 나인스퀘어) 마곡동 800, 101,102,103호',
#   '02-2664-7876'],
#  ['전북 전주시 덕진구',
#   '전주아중점',
#   '영업중',
#   '전라북도 전주시 덕진구 아중로 193 (우아동2가) 1,2층 ',
#   '063-246-2203'],
#  ['충북 청주시 상당구', '청주명암레이크점', '영업중', '충북 청주시 상당구 용담동 449  .', '0507-1384-9696'],
#  ['인천 중구',
#   '인천공항T1점',
#   '영업중',
#   '인천광역시 중구 공항로 272 (운서동, 인천공항) 인천국제공항 제1여객터미널 L/S 1층',
#   '032-743-3716'],
#  ['경기 이천시',
#   '이천하이닉스점',
#   '영업중',
#   '경기도 이천시 부발읍 경충대로 2091 연구개발동 1층',
#   '031-8094-8747'],
#  ['서울 강북구',
#   '수유사거리점',
#   '영업중',
#   '서울특별시 강북구 도봉로82길 11 (번동) 2~4층 ',
#   '070-5226-1999'],
#  ['서울 중구',
#   '명동퍼시픽호텔점',
#   '영업중',
#   '서울특별시 중구 퇴계로20길 2 (남산동2가, 퍼시픽호텔) 1층 ',
#   '02-3789-8747'],
#  ['충남 천안시 서북구',
#   '천안펜타포트점',
#   '영업중',
#   '충청남도 천안시 서북구 공원로 196 (불당동, 펜타포트) 5층',
#   '070-8820-3117'],
#  ['서울 송파구',
#   '아시아선수촌점',
#   '영업중',
#   '서울특별시 송파구 백제고분로 109 (잠실동) 1층~4층',
#   '02-412-3260'],
#  ['서울 동작구',
#   '보라매병원점',
#   '영업중',
#   '서울시 동작구 보라매로5길 20 서울특별시보라매병원 희망관 1층',
#   '02-831-3085'],
#  ['광주 광산구',
#   '광주수완2호점',
#   '영업중',
#   '광주광역시 광산구 수완로 73번길 7, 1층 (수완동)  1층',
#   '062-959-3327'],
#  ['경기 수원시 영통구',
#   '수원망포점',
#   '영업중',
#   '경기도 수원시 영통구 덕영대로1556번길 16 디지털엠파이어빌딩 125,126,127,212호 (영통동)',
#   '031-204-0065'],
#  ['세종 세종시',
#   '세종어반아트리움점',
#   '영업중',
#   '세종특별자치시 나성로 96 (나성동, 더센트럴) 101,102호',
#   '070-8800-3998'],
#  ['서울 서대문구',
#   '무악재역점',
#   '영업중',
#   '서울특별시 서대문구 통일로 360 (홍제동, 보하빌딩) .',
#   '02-6406-0046'],
#  ['대전 대덕구', '대전한남대점', '영업중', '대전 대덕구 한남로 65 .', '070-4109-5800'],
#  ['경기 이천시',
#   '(하)마장휴게소점',
#   '영업중',
#   '경기도 이천시 마장면중부고속도로82 마장휴게소 하행 통영방향',
#   '031-630-0001'],
#  ['경기 오산시',
#   '오산수청점',
#   '영업중',
#   '경기도 오산시 내삼미로79번길 46 (수청동 619-1) 101~104호 (수청동, 어반스페이스타워)',
#   '031-377-5823'],
#  ['서울 마포구',
#   '공덕점',
#   '영업중',
#   '서울특별시 마포구  마포대로 143 (공덕동, 마포공덕파크팰리스 Ⅱ) 1층 (114~121호)',
#   '02-701-5785'],
#  ['충남 예산군',
#   '(상)예산휴게소점',
#   '영업중',
#   '충청남도 예산군 신양면 당진영덕고속도로 33 (예산휴게소 상행) 당진 방향',
#   '없음'],
#  ['서울 중구', '약수역점', '영업중', '서울특별시 중구 다산로 114 (신당동,1~2층)', '02-2233-0866'],
#  ['대구 달서구',
#   '대구성서점',
#   '영업중',
#   '대구광역시 달서구 성서로 419, 국민연금대구사옥 1층 (이곡동 1198-5) 할리스',
#   '053-584-5702'],
#  ['경기 화성시',
#   '동탄점',
#   '영업중',
#   '경기도 화성시 동탄중심상가1길 5 (반송동, 동탄프라자) 1,2층',
#   '031-8003-9039'],
#  ['울산 남구',
#   '울산야음점',
#   '영업중',
#   '울산 남구 수암로 138, 타임스퀘어 상가 야음동 789-14, 101호',
#   '052-276-3535'],
#  ['서울 마포구', '홍대역점', '영업중', '서울특별시 마포구 어울마당로 111 (동교동) 2층', '02-323-7791'],
#  ['서울 성북구',
#   '고대안암병원점',
#   '영업중',
#   '서울특별시 성북구 고려대로 73 (안암동5가, 고려대병원) 고대안암병원 본관 3층 ',
#   '02-921-3062'],
#  ['서울 서대문구',
#   '신촌연세로점',
#   '영업중',
#   '서울특별시 서대문구 연세로 5, 1층 (창천동 30-7) 할리스',
#   '02-322-3684'],
#  ['경기 용인시 처인구',
#   '용인명지대점',
#   '영업중',
#   '경기도 용인시 처인구 명지로116번길 24-2 (남동) 1~2층',
#   '070-4042-3118'],
#  ['서울 용산구',
#   '용산아이파크몰 영풍문고점',
#   '영업중',
#   '서울특별시 용산구 한강대로23길 55 (한강로3가, 용산역) 용산역 리빙관 3층(한강로 3가)',
#   '070-8835-5073'],
#  ['전북 전주시 덕진구',
#   '국민연금공단점',
#   '영업중',
#   '전북 전주시 덕진구  기지로 170 국민연금공단 국민누리관 1층',
#   '063-221-5072'],
#  ['부산 금정구',
#   '부산금강식물원점',
#   '영업중',
#   '부산광역시 금정구 금샘로 22 (장전동) 1,2층 금정구 장전동 521-68외1필지 1,2층',
#   '051-517-1110'],
#  ['서울 영등포구',
#   '선유도역점TS카페',
#   '영업중',
#   '서울특별시 영등포구 양평로 96 (양평동4가) TS빌딩 1,2층',
#   '02-6267-6800'],
#  ['서울 구로구', '구로역점', '영업중', '서울특별시 구로구 새말로 18-29 (구로동) .', '02-862-3216'],
#  ['서울 마포구', '공덕역북카페점', '영업중', '서울특별시 마포구 마포대로 100 (공덕동, 공덕역) 북카페 지하1층', '없음'],
#  ['전북 부안군', '부안격포채석강점', '영업중', '전라북도 부안군 변산면 채석강길 22-10 .', '063-584-0011'],
#  ['대구 북구', '대구관음점', '영업중', '대구광역시 북구 구암로 59 비전스퀘어 1,2층 .', '053-324-6122'],
#  ['대전 서구',
#   '대전가장점',
#   '영업중',
#   '대전광역시 서구 도솔로 314  1층, 2층(괴정동, SL 빌딩)',
#   '042-365-0365'],
#  ['대전 유성구', '대전신성점', '영업중', '대전광역시 유성구 유성대로1184번길 18 (신성동) .', '042-862-3335'],
#  ['서울 성동구',
#   '왕십리역점',
#   '영업중',
#   '서울특별시 성동구 왕십리광장로 17 (행당동, 왕십리민자역사) 비트플렉스몰 3층 영풍문고 내',
#   '02-2200-1303'],
#  ['충남 천안시 서북구',
#   '천안쌍용점',
#   '영업중',
#   '충청남도 천안시 서북구 미라13길 16 (쌍용동) 쌍용동 955, 성건오피스텔 1층',
#   '041-563-4700'],
#  ['서울 영등포구',
#   '전경련회관점',
#   '영업중',
#   '서울특별시 영등포구 여의대로 24 (여의도동, 전국경제인연합회회관) 지하 1층 B109~111호 ',
#   '02-786-3485'],
#  ['부산 중구', '부산중앙역점', '영업중', '부산광역시 중구 대청로 148 (중앙동2가) .', '051-253-8883'],
#  ['경남 양산시',
#   '양산부산대병원치과동점',
#   '영업중',
#   '경상남도 양산시 물금읍 금오로 20, 양산부산대학교병원 치과병동 1층(범어리 2762-1) 할리스',
#   '070-4442-0608'],
#  ['경남 양산시',
#   '양산부산대병원본점',
#   '영업중',
#   '경상남도 양산시 물금읍 금오로 20, 양산부산대학교병원 중앙진료동 1층(범어리 2762-1) 할리스',
#   '055-362-4582'],
#  ['경기 하남시', '하남덕풍점', '영업중', '경기도 하남시 덕풍북로 2 (덕풍동) 1층', '031-792-9389'],
#  ['부산 사상구',
#   '부산백양대로점',
#   '영업중',
#   '부산광역시 사상구 백양대로 621, 2~4층(괘법동 141) 할리스',
#   '051-311-5399'],
#  ['인천 남동구',
#   '간석오거리점',
#   '영업중',
#   '인천광역시 남동구 남동대로 931 (간석동) 씨앤케이 웨딩홀',
#   '032-425-0915'],
#  ['서울 성동구',
#   '한양대병원점',
#   '영업중',
#   '서울특별시 성동구 왕십리로 222-1, 한양대학교병원 본관 1층 (사근동 110, 한양대학부속병원) 할리스',
#   '02-2281-2116'],
#  ['서울 서초구',
#   '서초마제스타시티점',
#   '영업중',
#   '서울특별시 서초구 서초대로38길 12 (서초동, 마제스타시티,힐스테이트서리풀) 1층',
#   '02-6411-0063'],
#  ['경기 시흥시', '월곶점', '영업중', '경기도 시흥시 월곶중앙로 63 (월곶동) .', '031-404-7966'],
#  ['대전 서구',
#   '대전만년점',
#   '영업중',
#   '대전광역시 서구 둔산대로117번길 95 (만년동, 리더스타운) 만년동 309',
#   '042-485-9777'],
#  ['경북 구미시', '(하)선산휴게소점', '영업중', '경상북도 구미시 옥성면 중부내륙고속도로 129 .', '.'],
#  ['경기 수원시', '화성융건릉점', '영업중', '경기도 화성시 효행로 501-3 1,2층', '031-224-6999'],
#  ['대전 서구',
#   '대전탄방점',
#   '영업중',
#   '대전광역시 서구 계룡로571번길 23-19 (탄방동) 1층 102호,103호,104호 / 탄방동 688',
#   '042-482-8425'],
#  ['전북 전주시 완산구',
#   '서전주DT점',
#   '영업중',
#   '전라북도 전주시 완산구 유연로 5 (효자동3가 1045-50) ',
#   '063-901-0802'],
#  ['경기 김포시',
#   '김포한강생태공원점',
#   '영업중',
#   '경기도 김포시 김포한강11로 452,1~2층  운양동 1264-4',
#   '031-996-2000'],
#  ['부산 동래구', '부산명륜역점', '영업중', '부산광역시 동래구 온천장로 5 (온천동) 1층', '051-557-7811'],
#  ['경남 진주시',
#   '진주평거점',
#   '영업중',
#   '경상남도 진주시 진양호로 46 (평거동) 1층,2층 (에스원빌딩)',
#   '055-745-9633'],
#  ['경기 수원시 영통구',
#   '아주대병원점',
#   '영업중',
#   '경기도 수원시 영통구 월드컵로 164 (원천동, 아주대학병원) 아주대학교병원 본관 1층',
#   '031-211-5718'],
#  ['대구 수성구', '대구수성못점', '영업중', '대구광역시 수성구 용학로 115 두산동 690', '053-761-5655'],
#  ['울산 남구', '울산시청점', '영업중', '울산광역시 남구 삼산로 60 (신정동) 1층', '070-7733-7108'],
#  ['대구 동구', '동대구역사점', '영업중', '대구광역시 동구 동대구로 550 (동대구역 내 1층)', '053-942-1033'],
#  ['서울 종로구', '종로5가점', '영업중', '서울특별시 종로구 동호로 401(종로5가) .', '02-2266-1989'],
#  ['부산 북구',
#   '부산덕천점',
#   '영업중',
#   '부산광역시 북구 덕천1길 21, 1~2층 (덕천동 400-14) 할리스',
#   '051-342-8835'],
#  ['인천 부평구',
#   '부평로데오점',
#   '영업중',
#   '인천광역시 부평구 시장로 17-1 (부평동, 인일 빌딩) 1,2,3층',
#   '032-505-7130'],
#  ['충북 청주시 흥덕구', '충북오송점', '영업중', '충청북도 청주시 흥덕구 오송읍 만수1길 3 .', '043-239-0075'],
#  ['서울 영등포구',
#   '여의도파이낸스타워점',
#   '영업중',
#   '서울특별시 영등포구 국제금융로2길 32, 여의도파이낸스타워 1층(여의도동 23-8)',
#   '02-761-3154'],
#  ['경기 김포시',
#   '김포농협본점',
#   '영업중',
#   '경기도 김포시 홍도평로 20 (걸포동) 김포농협하나로마트본점 2층',
#   '031-986-7932'],
#  ['경기 남양주시',
#   '다산지금점',
#   '영업중',
#   '경기도 남양주시 다산중앙로82번안길 143-15 101호',
#   '070-7778-2409'],
#  ['서울 종로구',
#   '서울대병원점',
#   '영업중',
#   '서울특별시 종로구 대학로 101 (연건동, 서울대학교의과대학)',
#   '02-741-5815'],
#  ['서울 영등포구', '구로디지털뉴스테이점', '영업중', '서울시 영등포구 시흥대로 595 105호', '070-7547-4100'],
#  ['경북 경주시', '경주보불로점', '영업중', '경북 경주시 보불로 305 .', '054-744-7700'],
#  ['울산 북구', '울산명촌점', '영업중', '울산광역시 북구 명촌로 59 .', '052-289-9905'],
#  ['전북 김제시', '전북김제점', '영업중', '전북 김제시 검산택지 5길 21-10 1층', '063-547-9600'],
#  ['대구 북구', '대구침산네거리점', '영업중', '대구광역시 북구 침산남로 157 (침산동) .', '053-353-5544'],
#  ['대구 동구', '대구반야월점', '영업중', '대구광역시 동구 안심로 255 .', '053-961-7007'],
#  ['서울 종로구',
#   '센터포인트점',
#   '영업중',
#   '서울특별시 종로구 새문안로5길 31, 센터포인트광화문빌딩 1층 (도렴동 65, 센터포인트 광화문) 할리스',
#   '02-6031-6213'],
#  ['서울 마포구',
#   '홍대입구역점',
#   '영업중',
#   '서울특별시 마포구 양화로 151, 1층 (동교동 160-1) 할리스',
#   '02-322-3584'],
#  ['경기 고양시 일산동구',
#   '마두역점',
#   '영업중',
#   '경기도 고양시 일산동구 중앙로 1165, 1층일부 1층',
#   '070-8866-7558'],
#  ['전북 군산시', '군산미장점', '영업중', '전라북도 군산시 미장안길 54  통큰타운3동 105호', '063-442-8777'],
#  ['서울 서초구',
#   '백석예술대학교점',
#   '영업중',
#   '서울특별시 서초구 방배로9길 23 (방배동, 백석예술대학교) 3층',
#   '02-585-9150'],
#  ['대전 중구',
#   '대전오류점',
#   '영업중',
#   '대전광역시 중구 계룡로 876 메종드메디컬빌딩 104호, 202호 오류동 151-3',
#   '042-522-3141'],
#  ['서울 강남구',
#   '카페테리아&삼성점',
#   '영업중',
#   '서울시 강남구 삼성로 512, 10층 인터파크 카페테리아 (삼성동) .',
#   '2188-7100'],
#  ['서울 강남구',
#   '역삼테헤란점',
#   '영업중',
#   '서울특별시 강남구 테헤란로 131, 한국지식재산센터 1층 (역삼동 647-9) 할리스',
#   '02-501-3573'],
#  ['대구 달성군', '대구현풍테크노점', '영업중', '대구시 달성군 유가읍 테크노공원로 65 .', '053-267-3338'],
#  ['전남 장흥군', '전남장흥점', '영업중', '전라남도 장흥군 장흥읍 북부로 18 .', '061-862-0119'],
#  ['경기 화성시', '화성병점점', '영업중', '경기도 화성시 병점동로 105 1,2층(진안동)', '031-239-0455'],
#  ['경기 구리시', '구리수택점', '영업중', '경기도 구리시 검배로 73 (수택동) 할리스', '031-551-0988'],
#  ['서울 관악구', '난곡사거리점', '영업중', '서울 관악구 남부순환로 1489 신림동 526-13', '02-865-0012'],
#  ['서울 양천구', '신정네거리역점', '영업중', '서울특별시 양천구 중앙로 252 2층 .', '02-2645-9957'],
#  ['경북 구미시',
#   '구미CGV점',
#   '영업중',
#   '경상북도 구미시 구미중앙로 44 (원평동, 멀티복합상가) 원평동 68-1, 1층',
#   '054-604-0375'],
#  ['경기 부천시 원미구',
#   '역곡역점',
#   '영업중',
#   '경기 부천시 부일로726번길 5 (역곡동 80) 역곡역 2번출구 사거리에서 가톨릭대학교방향 좌회전 후 약 50M',
#   '070-8887-4965'],
#  ['경기 오산시',
#   '오산대역DT점',
#   '영업중',
#   '경기도 오산시 경기대로 491 (수청동) 1층~3층 할리스',
#   '031-372-9750'],
#  ['서울 중구',
#   '을지로입구점',
#   '영업중',
#   '서울특별시 중구 명동3길 23 (을지로2가) 1~4층 할리스 ',
#   '02-318-6381'],
#  ['경북 구미시',
#   '구미금오산점',
#   '영업중',
#   '경상북도 구미시 금오산로 209 (남통동) 할리스커피 구미금오산점 ',
#   '054-441-4452'],
#  ['경기 화성시',
#   '(하)매송휴게소점',
#   '영업중',
#   '경기 화성시 매송면 서해안고속도로 315 목포방향 서해안고속도로 315 목포방향',
#   '010-8883-8045'],
#  ['경기 화성시',
#   '(상)매송휴게소점',
#   '영업중',
#   '경기 화성시 매송면 서해안고속도로 316 서울방향 .',
#   '010-7319-1449'],
#  ['경남 창원시 의창구',
#   '창원팔용점',
#   '영업중',
#   '경상남도 창원시 의창구 창원대로18번길 6-8 (팔용동) .',
#   '055-298-3434'],
#  ['전북 전주시 완산구',
#   '전주남천교점',
#   '영업중',
#   '전라북도 전주시 완산구 전주천서로 81  동서학동 66',
#   '063-232-6000'],
#  ['부산 연제구', '부산연산점', '영업중', '부산광역시 연제구 반송로 89 (연산동) 1층', '051-989-3296'],
#  ['대구 북구',
#   '대구침산점',
#   '영업중',
#   '대구 북구 성북로 36,2층 601,602,603,604 473-3, 침산초등학교 맞은편',
#   '053-353-5412'],
#  ['대구 동구', '대구안심점', '영업중', '대구시 동구 안심로 90길29 .', '053-963-2223'],
#  ['강원 홍천군', '(하)홍천휴게소점', '영업중', '강원도 홍천군 화촌면 서울양양고속도로 84 .', '.'],
#  ['경기 화성시', '동탄카림애비뉴점', '영업중', '경기도 화성시 동탄대로시범길 134 0001호 .', '031-372-1650'],
#  ['대구 중구',
#   '대구동성로점',
#   '영업중',
#   '대구광역시 중구 동성로6길 32, B1~2층 (공평동 52-2) 할리스',
#   '053-252-6307'],
#  ['서울 은평구', '응암역점', '영업중', '서울특별시 은평구 증산로 475 .', '02-3152-2910'],
#  ['경남 창원시 성산구',
#   '상남중앙점',
#   '영업중',
#   '경상남도 창원시 성산구 마디미로38번길 11 (상남동 25) 할리스',
#   '055-261-5925'],
#  ['인천 남구',
#   '인천주안역점',
#   '영업중',
#   '인천광역시 미추홀구 주안로 105 1,2층 주안동 130-10 /남구->미추홀구 변경',
#   '032-425-1793'],
#  ['울산 남구', '울산삼산대로점', '영업중', '울산광역시 남구 정동로 71 (삼산동) 삼산동', '052-293-2234'],
#  ['경기 구리시',
#   '구리장자호수공원점',
#   '영업중',
#   '경기도 구리시 장자대로 86번길 18 1,2층 (참참존빌딩)',
#   '031-568-7232'],
#  ['서울 서대문구',
#   '이대점',
#   '영업중',
#   '서울특별시 서대문구 이화여대길 59 (대현동, 메르체쇼핑몰) 엘큐브 3층',
#   '02-392-1008'],
#  ['대구 동구',
#   '동대구환승센터점',
#   '영업중',
#   '대구광역시 동구 동부로 149 (신천동, 신세계동대구복합환승센터) 3층',
#   '053-742-0614'],
#  ['경기 수원시', '수원경인일보점', '영업중', '경기도 수원시 팔달구 효원로 299 .', '031-226-0530'],
#  ['부산 수영구',
#   '부산광안해변점',
#   '영업중',
#   '부산광역시 수영구 광안해변로 251 (민락동) 178-5',
#   '051-752-4551'],
#  ['경기 파주시', '파주야당역점', '영업중', '경기도 파주시 경의로 1042 (야당동) 1,2층', '031 946 4823'],
#  ['서울 양천구',
#   '목동예술인회관점',
#   '영업중',
#   '서울시 양천구 목동서로 225, 예술인회관 1층 1층',
#   '02-2655-1300'],
#  ['경기 고양시 덕양구',
#   '원당점',
#   '영업중',
#   '경기도 고양시 덕양구 호국로 797, 대동피렌체 104~106호 1층',
#   '031-964-7785'],
#  ['충북 괴산군',
#   '(하)괴산휴게소점',
#   '영업중',
#   '충북 괴산군 장연면 중부내륙고속도로 205 괴산(마산방향)휴게소  할리스커피',
#   '043-832-7966'],
#  ['전남 보성군',
#   '(상)보성녹차휴게소점',
#   '영업중',
#   '전라남도 보성군 미력면 남해고속도로 63 (보성녹차(목포)주유소) 목포방향',
#   '070-4325-8801'],
#  ['전남 보성군', '(하)보성녹차휴게소점', '영업중', '전남 보성군 겸백면 남해고속도로 70 .', '070-4325-8808'],
#  ['서울 강남구',
#   '선릉샹제리제점',
#   '영업중',
#   '서울특별시 강남구 테헤란로 406 (대치동, 샹제리제센터) 1층',
#   '02-501-4255'],
#  ['경기 양주시', '양주고읍점', '영업중', '경기도 양주시 고읍남로 10 (광사동) 1,2층', '031-843-0078'],
#  ['인천 연수구',
#   '인천연수CGV점',
#   '영업중',
#   '인천 연수구 청능대로 210 (스쿼어원 4층) 동춘동 926 ',
#   '032-456-4499'],
#  ['경북 김천시',
#   '(상)추풍령휴게소점',
#   '영업중',
#   '경북 김천시 봉산면 경부고속도로 214-1 광천리 737-1 (서울방향)',
#   '054-439-3187'],
#  ['울산 북구', '울산풍차DT점', '영업중', '울산광역시 북구 산업로 1440 신천동 456', '052-292-8181'],
#  ['서울 서초구',
#   '(하)만남의광장점',
#   '영업중',
#   '서울특별시 서초구 양재대로12길 73-71 (원지동, 만남의광장) 할리스커피',
#   '02-578-3372'],
#  ['경기 시흥시',
#   '시흥하늘휴게소점',
#   '영업중',
#   '경기도 시흥시 수도권제1순환고속도로 105-1 (조남동) 조남동 15-10',
#   '010-8326-4908'],
#  ['대전 서구', '대전타임월드점', '영업중', '대전광역시 서구 둔산로 32-13 (둔산동) .', '042-489-1315'],
#  ['전남 무안군',
#   '남악신도시점',
#   '영업중',
#   '전라남도 무안군 삼향읍 남악로 234 트리폴리앙 B동 1, 108호 .',
#   '061-282-8280'],
#  ['부산 기장군', '(상)장안휴게소점', '영업중', '부산광역시 기장군 장안읍 동해고속도로 26 .', '051-727-3714'],
#  ['부산 기장군',
#   '(하)장안휴게소점',
#   '영업중',
#   '부산광역시 기장군 장안읍 동해고속도로 25 (장안휴게소하행) .',
#   '051-727-3647'],
#  ['서울 중구',
#   '충무로역점',
#   '영업중',
#   '서울특별시 중구 퇴계로36길 2 (필동2가, 동국대학교충무로영상센터) .',
#   '02-2268-8960'],
#  ['경기 이천시',
#   '(상)마장휴게소점',
#   '영업중',
#   '경기도 이천시 마장면 중부고속도로 82 마장휴게소 상행 하남방향',
#   '031-630-0001'],
#  ['세종 세종시', '세종소담DI점', '영업중', '세종특별자치시 소담로 40 소담동 570', '044-862-9027'],
#  ['부산 중구', '부산BIFF광장점', '영업중', '부산 중구 비프광장로 31-1, 1층 .', '051-242-6552'],
#  ['부산 동구',
#   '부산역사점',
#   '영업중',
#   '부산광역시 동구 중앙대로 206 (초량동, 한국철도공사부산지역본부) 2충 초량동 1187-1',
#   '051-441-0918'],
#  ['광주 북구', '광주일곡점', '영업중', '광주광역시 북구 송해로 81 일곡동 821-5  1~3층', '070-7716-0123'],
#  ['경기 양주시', '양주점', '영업중', '경기도 양주시 평화로 1407 (덕계동) .', '031-868-5779'],
#  ['충남 당진시', '당진푸르지오점', '영업중', '충청남도 당진시 읍내동 1590 1층 희은빌라 .', '041-354-2004'],
#  ['대전 유성구', '대전전민점', '영업중', '대전광역시 유성구 전민로22번길 62 전민동 306-1', '042-389-2831'],
#  ['강원 홍천군', '홍천점', '영업중', '강원도 홍천군 홍천읍 꽃뫼로 98 .', '033-432-3368'],
#  ['전남 목포시', '목포하당점', '영업중', '전라남도 목포시 비파로51번길 37 (상동) .', '061-283-9800'],
#  ['경북 김천시', '김천혁신도시점', '영업중', '경상북도 김천시 혁신로 246 .', '054-433-4333'],
#  ['대구 서구', '대구팔달교DT점', '영업중', '대구광역시 서구 팔달로 34 .', '053-341-9595'],
#  ['경기 남양주시', '별내카페거리점', '영업중', '경기도 남양주시 두물로39번길 33 (별내동) .', '031-574-5655'],
#  ['경기 파주시', '파주탄현점', '영업중', '경기도 파주시 탄현면 방촌로 1017 1,2층', '031-957-9477'],
#  ['경기 안성시', '(상)안성휴게소점', '영업중', '경기도 안성시 원곡면 산하리 67-3  000', 'x'],
#  ['광주 광산구', '광주우산점', '영업중', '광주광역시 광산구 풍영철길로 12 (우산동) 1층', '062-956-6582'],
#  ['전북 군산시', '군산수송점', '영업중', '전라북도 군산시 수송북로 22 수송동 831-1,1층', '063-467-9500'],
#  ['경기 화성시', '동탄호수공원점', '영업중', '경기도 화성시 동탄면 동탄순환대로5길 15 .', '031-373-5223'],
#  ['경기 수원시',
#   '수원인계점',
#   '영업중',
#   '경기도 수원시 팔달구 인계로138번길 49 (인계동) 인계동 1038-12',
#   '031-222-6842'],
#  ['인천 중구',
#   '영종하늘도시점',
#   '영업중',
#   '인천 중구 하늘달빛로 90-21 1,2층 중산동 1876-9',
#   '032-752-1761'],
#  ['서울 서대문구', '서대문역점', '영업중', '서울특별시 서대문구 통일로9안길 28 (충정로2가) 1층', '02-313-0807'],
#  ['부산 동구', '동부산우체국점', '영업중', '부산광역시 동구 조방로 15, 1층  .', '051-631-3193'],
#  ['경기 안산시 단원구', '안산로데오점', '영업중', '경기도 안산시 단원구 중앙대로 907 .', '031-405-7337'],
#  ['경기 안성시', '안성팜랜드점', '영업중', '경기도 안성시 공도읍 대신두길 28, 안성팜랜드 .', '070-4228-7345'],
#  ['경남 양산시', '양산원동점', '영업중', '경상남도 양산시 원동면 원동로 1429 .', '055-372-0268'],
#  ['광주 서구', '광주금호점', '영업중', '광주광역시 서구 운천로 3 (금호동 762-6) 1층', '062-385-0725'],
#  ['인천 서구',
#   '인천엠파크허브점',
#   '영업중',
#   '인천광역시 서구 염곡로 52, 엠파크 허브동 103호 (가좌동 150-19) .',
#   '032-265-0103'],
#  ['대구 달서구', '대구본리점', '영업중', '대구광역시 달서구 장기로 203 (본리동 62-16) .', '053-553-3002'],
#  ['대구 달서구', '대구월성CGV점', '영업중', '대구광역시 달서구 조암로 29 이래타워 4F 월성동, 616', '없음'],
#  ['부산 강서구',
#   '명지국제신도시점',
#   '영업중',
#   '부산광역시 강서구 명지국제11로 57  명지동 3334-4',
#   '051-271-5600'],
#  ['광주 서구',
#   '유스퀘어CGV점',
#   '영업중',
#   '광주광역시 서구 무진대로 904, 유스퀘어 2층 (광천동, 49-1) .',
#   '062-351-4687'],
#  ['광주 북구', '광주오치점', '영업중', '광주광역시 북구 서하로 185 (오치동 862-21) 1층', '062-251-5684'],
#  ['광주 광산구',
#   '광주운남점',
#   '영업중',
#   '광주광역시 광산구 하남대로 248-13 (운남동 771-3 ) 1층',
#   '062-951-5979'],
#  ['전북 익산시',
#   '익산어양점',
#   '영업중',
#   '전라북도 익산시 동서로63길 4, 101호 (어양동, 하모니시티) 1층',
#   '063-832-4700'],
#  ['전북 전주시 덕진구',
#   '전주백제대로점',
#   '영업중',
#   '전라북도 전주시 덕진구 백제대로 592 (금암동) 1층',
#   '063-271-5056'],
#  ['경기 의정부시',
#   '의정부민락점',
#   '영업중',
#   '경기도 의정부시 오목로205번길 55 (민락동, 메가타워) .',
#   '031-851-3633'],
#  ['충남 천안시 동남구',
#   '동천안우체국점',
#   '영업중',
#   '충청남도 천안시 동남구 청수5로 10, 1층 .',
#   '041-522-5024'],
#  ['경남 사천시',
#   '(상)사천휴게소점',
#   '영업중',
#   '경상남도 사천시 곤양면 묵실길 31-11 (순천방향) .',
#   '055-854-3574'],
#  ['경남 사천시',
#   '(하)사천휴게소점',
#   '영업중',
#   '경상남도 사천시 곤양면 서삼로 619 (부산방향) .',
#   '055-854-3134'],
#  ['전북 전주시 완산구',
#   '전북도청점',
#   '영업중',
#   '전라북도 전주시 완산구 홍산남로 51, 102~103호 일부(효자동3가) 1층',
#   '063-228-4005'],
#  ['전북 부안군', '전북부안점', '영업중', '전라북도 부안군 부안읍 석정로 269, 1층 .', '063-581-0620'],
#  ['서울 성동구', '한양대시티빌점', '영업중', '서울특별시 성동구 마조로1가길 9 (행당동) .', '02-2299-9934'],
#  ['강원 동해시', '동해촛대바위점', '영업중', '강원도 동해시 촛대바위길 16 (추암동 1-6) .', '033-522-0117'],
#  ['경북 경산시', '경산중방점', '영업중', '경상북도 경산시 경안로 205, 2층 .', '053-814-9980'],
#  ['울산 북구',
#   '울산공항1호점',
#   '영업중',
#   '울산광역시 북구 산업로 1103 울산공항 2층 일반대합실 화봉동 1140-16',
#   '052-289-5525'],
#  ['울산 북구',
#   '울산공항2호점',
#   '영업중',
#   '울산광역시 북구 산업로 1103 울산공항 2층 격리대합실 화봉동 1140-16',
#   '없음'],
#  ['서울 서초구', '논현역점', '영업중', '서울특별시 서초구 신반포로 332 (반포동, 우진빌딩) 1층', '02-515-1162'],
#  ['부산 서구', '부산송도점', '영업중', '부산광역시 서구 송도해변로 61-1 .', '051-255-6100'],
#  ['경기 평택시', '평택서재점', '영업중', '경기도 평택시 서재로 26-24 (동삭동) 1,2층 .', '031-651-2750'],
#  ['강원 원주시', '원주단계택지점', '영업중', '강원도 원주시 장미공원길 27-9 .', '033-745-5007'],
#  ['서울 강남구',
#   '수서점',
#   '영업중',
#   '서울특별시 강남구 밤고개로1길 10 (수서동, 수서현대벤쳐빌) 지하1층',
#   '02-451-0723'],
#  ['경기 수원시', '수원오목천점', '영업중', '경기도 수원시 권선구 서수원로 179 1~2층', '031-291-7933'],
#  ['경북 군위군', '(상)군위휴게소점', '영업중', '경상북도 군위군 군위읍 경북대로 4084 부산방향', '054-383-6114'],
#  ['경남 양산시', '양산신도시점', '영업중', '경상남도 양산시 물금읍 야리로 127 .', '055-366-0268'],
#  ['전북 전주시 덕진구',
#   '전북대덕진광장점',
#   '영업중',
#   '전라북도 전주시 덕진구 덕진광장로12, 1~2층(덕진동1가) 1층',
#   '063-272-2400'],
#  ['전북 남원시',
#   '(상)지리산휴게소점',
#   '영업중',
#   '전라북도 남원시 아영면 광주대구고속도로 76 (대구방면)',
#   '063-636-7191'],
#  ['전북 남원시',
#   '(하)지리산휴게소점',
#   '영업중',
#   '전라북도 남원시 아영면 광주대구고속도로 75 (지리산휴게소(하)광주방면) (광주, 고서,담양방면)',
#   '063-636-7195'],
#  ['전남 여수시',
#   '여수웅천점',
#   '영업중',
#   '전라남도 여수시 예울마루로 35-24 (웅천동) 웅천동 1699-3',
#   '061-681-2522'],
#  ['대구 달서구', '대구장기점', '영업중', '대구광역시 달서구 장기로 268 .', '053-522-0666'],
#  ['경북 성주군',
#   '(상)남성주휴게소점',
#   '영업중',
#   '경상북도 성주군 용암면 중부내륙고속도로 76 (본리리, 남성주(양평방향)휴게소) 양평방향',
#   '054-931-5742'],
#  ['서울 서초구',
#   '고속터미널영동선점',
#   '영업중',
#   '서울특별시 서초구 신반포로 194 (반포동, 강남고속버스터미널) 2층 A-2호',
#   '02-591-1555'],
#  ['충북 옥천군',
#   '(상)옥천휴게소점',
#   '영업중',
#   '충청북도 옥천군 옥천읍 옥천동이로 242-34 (매화리, 옥천상휴게소) .',
#   '043-731-8096'],
#  ['세종 세종시',
#   '세종어진점',
#   '영업중',
#   '세종특별자치시 절재로 194 (어진동, 중앙타운) 133호,214호 .',
#   '070-7766-1589'],
#  ['대구 북구', '대구동천점', '영업중', '대구광역시 북구 동천로 125 (동천동) .', '053-321-0099'],
#  ['경북 경주시',
#   '(상)외동휴게소점',
#   '영업중',
#   '경상북도 경주시 외동읍 석계리 970번지 상석길 58-70',
#   '054-745-0631'],
#  ['경북 성주군',
#   '(하)남성주휴게소점',
#   '영업중',
#   '경상북도 성주군 선남면 중부내륙고속도로 77 (명포리, 남성주(창원방향)휴게소) 창원방향',
#   '054-933-7105'],
#  ['경기 안양시', '안양역점', '영업중', '경기도 안양시 만안구 장내로139번길 61 .', '031-466-2879'],
#  ['대전 유성구',
#   '대전도안마을점',
#   '영업중',
#   '대전광역시 유성구 도안대로 560 (봉명동, 도안마을1단지) .',
#   '042-826-6080'],
#  ['전북 전주시 덕진구',
#   '전주하가점',
#   '영업중',
#   '전라북도 전주시 덕진구 가련산로 25 (덕진동2가) 1층',
#   '063-275-1230'],
#  ['서울 구로구',
#   '구로점',
#   '영업중',
#   '서울특별시 구로구 디지털로34길 55 (구로동, 코오롱싸이언스밸리2차) 1층',
#   '02-2025-0255'],
#  ['경기 고양시 덕양구', '고양행신점', '영업중', '경기도 고양시 덕양구 충경로 37 (행신동) 1층', '031-938-4055'],
#  ['대구 수성구', '대구범어점', '영업중', '대구광역시 수성구 범어천로 44 (범어동) .', '053-761-2187'],
#  ['경기 수원시', '인계써드아이점', '영업중', '경기도 수원시 팔달구 인계로 130 (인계동) 1층', '031-232-0727'],
#  ['충남 아산시',
#   '아산우체국점',
#   '영업중',
#   '충청남도 아산시 시민로 455 (온천동, 아산우체국) .',
#   '041-548-5024'],
#  ['충남 천안시 서북구',
#   '천안두정역점',
#   '영업중',
#   '충청남도 천안시 서북구 두정로 238 (두정동) .',
#   '041-566-5148'],
#  ['강원 동해시', '동해묵호점', '영업중', '강원도 동해시 해안로 368 (평릉동, 시드니) .', '033-534-8902'],
#  ['경북 경주시', '경주황성점', '영업중', '경상북도 경주시 황성로28번길 15 .', '054-701-1234'],
#  ['서울 금천구',
#   '가산디지털단지점',
#   '영업중',
#   '서울특별시 금천구 가산디지털1로 186 (가산동, 제이플라츠) .',
#   '02-2028-7111'],
#  ['전남 목포시', '목포평화점', '영업중', '전라남도 목포시 미항로 129 .', '061-285-0365'],
#  ['충북 단양군',
#   '(하)단양휴게소점',
#   '영업중',
#   '충청북도 단양군 적성면 기동리 산 74-1 (중앙고속도로 부산방향) 기동리 423-1',
#   '043-423-5401'],
#  ['대전 유성구', '대전반석역점', '영업중', '대전광역시 유성구 반석동로40번길 40 (반석동) .', '042-714-5808'],
#  ['광주 동구',
#   '광주조선대점',
#   '영업중',
#   '광주광역시 동구 필문대로273번길 12, 1,2층(지산동) .',
#   '062-416-3647'],
#  ['전북 고창군', '전북고창점', '영업중', '전라북도 고창군 고창읍 중앙로 195 (읍내리) .', '063-564-3357'],
#  ['경남 거창군',
#   '(상)거창휴게소점',
#   '영업중',
#   '경상남도 거창군 가조면 가조가야로 1523 (도리, 거창휴게소(상)) .',
#   '055-943-0992'],
#  ['경남 양산시',
#   '(서)양산휴게소점',
#   '영업중',
#   '경상남도 양산시 동면 목장길 15-50 (내송리, 양산휴게소) .',
#   '055-384-0144'],
#  ['경남 거창군',
#   '(하)거창휴게소점',
#   '영업중',
#   '경상남도 거창군 가조면 가조가야로 1543-81 .',
#   '055-943-0992'],
#  ['경기 고양시 일산동구',
#   '평촌스마트스퀘어점',
#   '영업중',
#   '경기도 안양시 동안구 시민대로 311, 110호/111호(관양동, 금강스마트빌딩) .',
#   '031-421-8097'],
#  ['충북 청주시 청원구',
#   '청주성모병원점',
#   '영업중',
#   '충청북도 청주시 청원구 주성로 173-19, 청주성모병원 본관 주중동 589-5',
#   '070-7761-0015'],
#  ['경기 안성시',
#   '(하)안성휴게소점',
#   '영업중',
#   '경기도 안성시 원곡면 경부고속도로 365 안성휴게소(부산방향) .',
#   '031-655-0531'],
#  ['대전 서구',
#   '대전롯데점',
#   '영업중',
#   '대전광역시 서구 용문로 41-80, 리베라 아이누리주상복합 101 .',
#   '042-528-2155'],
#  ['경기 고양시 일산동구',
#   '라페스타입구점',
#   '영업중',
#   '경기도 고양시 일산동구 중앙로1275번길 38-15 삼희포시즌프라자 1층 1층',
#   '031-904-1991'],
#  ['경기 의정부시', '의정부시청점', '영업중', '경기도 의정부시 시민로 57 .', '031-826-0009'],
#  ['충북 청주시 청원구', '청주율량점', '영업중', '충청북도 청주시 청원구 1순환로 122 .', '043-216-1990'],
#  ['대전 서구', '대전관저점', '영업중', '대전광역시 서구 관저중로64번길 26 1,2층 .', '042-542-8080'],
#  ['인천 서구', '인천검단사거리점', '영업중', '인천 서구 검단로 465 .', '070-7766-4494'],
#  ['전북 전주시 완산구', '전주혁신도시점', '영업중', '전라북도 전주시 완산구 오공로 33 1~2층', '063-221-3361'],
#  ['충남 천안시 서북구',
#   '천안두정점',
#   '영업중',
#   '충청남도 천안시 서북구 오성6길 52, 1층 두정동 779',
#   '041-574-0013'],
#  ['강원 원주시', '(춘)치악휴게소점', '영업중', '강원도 원주시 신림면 다리실2길 32 0000', '033-762-8129'],
#  ['서울 영등포구', '대림역점', '영업중', '서울특별시 영등포구 도림로 140 (대림동, 대림빌딩) .', '02-834-1000'],
#  ['경기 평택시', '평택점', '영업중', '경기도 평택시 평택1로 11 .', '031-651-1223'],
#  ['충북 진천군', '충북진천점', '영업중', '충청북도 진천군 진천읍 중앙북로 28 2층 .', '043-534-8584'],
#  ['인천 서구', '청라센터시아점', '영업중', '인천 서구 중봉대로 612번길 16 1층 연희동', '032-567-1192'],
#  ['경기 김포시', '김포골드밸리점', '영업중', '경기도 김포시 양촌읍 황금로109번길 27 1층', '031-998-7233'],
#  ['서울 서초구',
#   '남부터미널점',
#   '영업중',
#   '서울특별시 서초구 서초중앙로 52 (서초동, 영진빌딩) 서초동 1623-10',
#   '02-584-9500'],
#  ['서울 강동구', '고덕리앤파크점', '영업중', '서울특별시 강동구 상일로 151 (고덕동) 1층', '02-441-1121'],
#  ['강원 원주시', '원주중앙점', '영업중', '강원도 원주시 중평길 4, 2~4층 .', '033-748-1188'],
#  ['전북 전주시 덕진구',
#   '전주송천점',
#   '영업중',
#   '전라북도 전주시 덕진구 송천로 1, 1-2블럭 2-112,113,136호 1층',
#   '063-275-3308'],
#  ['전북 전주시 덕진구',
#   '송천솔내점',
#   '영업중',
#   '전라북도 전주시 덕진구 붓내3길 17 송천동 2가 244-10, 1층',
#   '063-291-8000'],
#  ['서울 강남구', '한티역점', '영업중', '서울특별시 강남구 도곡로 414 (대치동, 삼성빌딩) .', '02-538-8886'],
#  ['강원 강릉시', '강릉항마리나점', '영업중', '강원도 강릉시 창해로14번길 51-20 .', '070-8816-6543'],
#  ['광주 광산구', '광주첨단점', '영업중', '광주광역시 광산구 첨단중앙로 136 1층', '062-434-0200'],
#  ['부산 수영구',
#   '부산수영로터리점',
#   '영업중',
#   '부산광역시 수영구 수영로 710-1, 프라임메디컬빌딩 2층 201 .',
#   '070-4239-7541'],
#  ['경기 고양시 일산서구',
#   '일산레이킨스몰점',
#   '영업중',
#   '경기도 고양시 일산서구 호수로 817 레이킨스몰 138 1층',
#   '031 916 1289'],
#  ['강원 원주시', '(부)치악휴게소점', '영업중', '강원도 원주시 신림면 치악로 416 0', '033-762-8128'],
#  ['인천 남동구', '간석역남부점', '영업중', '인천 남동구 석산로 11 .', '032-427-7935'],
#  ['서울 중구',
#   '충정래미안점',
#   '영업중',
#   '서울특별시 중구 중림로 21 (중림동, 더플레이스충정로) B204호',
#   '02-363-1388'],
#  ['경기 수원시', '수원성대역점', '영업중', '경기도 수원시 장안구 서부로2126번길 10 1층', '031-309-1660'],
#  ['광주 서구', '광주풍암점', '영업중', '광주광역시 서구 풍금로38번길 11 .', '062-652-5505'],
#  ['서울 동작구', '노량진역점', '영업중', '서울특별시 동작구 노량진로 157 (노량진동) 2층', '02-827-0280'],
#  ['충북 청주시 흥덕구', '충북대점', '영업중', '충청북도 청주시 흥덕구 내수동로 53 1~2층', '043-266-2248'],
#  ['경북 군위군',
#   '(하)군위휴게소점',
#   '영업중',
#   '경상북도 군위군 군위읍 경북대로 4082 춘천방향',
#   '070-4162-5309'],
#  ['서울 강동구',
#   '굽은다리역점',
#   '영업중',
#   '서울특별시 강동구 양재대로 1591 , 1층 (천호동 31-2)',
#   '02-488-5077'],
#  ['인천 연수구',
#   '송도IT점',
#   '영업중',
#   '인천 연수구 송도과학로 32, 송도테크노파크IT센터 1층-A104호 .',
#   '032-209-7979'],
#  ['경북 문경시', '(하)문경휴게소점', '영업중', '경상북도 문경시 중부내륙고속도로 173 .', '054-554-1655'],
#  ['서울 관악구',
#   '서울대사거리점',
#   '영업중',
#   '서울특별시 관악구 관악로 172, 2층 봉천동 857-4',
#   '02-877-6070'],
#  ['서울 강남구',
#   '도심공항점',
#   '영업중',
#   '서울특별시 강남구 테헤란로87길 22 (삼성동, 한국도심공항터미널, 2층)   .',
#   '02-2016-5400'],
#  ['서울 종로구',
#   '광화문LG점',
#   '영업중',
#   '서울특별시 종로구 새문안로 58 (신문로2가, LG광화문빌딩) 1층, 지하1층',
#   '02-720-6994'],
#  ['서울 광진구',
#   '건대입구점',
#   '영업중',
#   '서울특별시 광진구 아차산로 235 (화양동)  235 (화양동)',
#   '02-463-1983'],
#  ['서울 중구', '광화문점', '영업중', '서울특별시 중구 세종대로21길 55 (태평로1가) 1층', '02-738-8004'],
#  ['서울 강남구', '청담점', '영업중', '서울특별시 강남구 학동로 517 (청담동) 1층', '02-515-9915'],
#  ['경남 진주시', '진주교대점', '영업중', '경상남도 진주시 진양호로 348 .', '055-745-3303'],
#  ['광주 남구', '광주봉선점', '영업중', '광주광역시 남구 봉선중앙로 21, 1층 1층', '062-651-7888'],
#  ['서울 동작구',
#   '이수역점',
#   '영업중',
#   '서울특별시 동작구 동작대로 83 (사당동, 헤라피스빌딩) 1층',
#   '02-588-4845'],
#  ['경기 안산시 단원구',
#   '안산NC고잔점',
#   '영업중',
#   '경기도 안산시 단원구 광덕대로 194  안산NC고잔점 A관 1층',
#   '031-436-4181'],
#  ['서울 서초구',
#   '방배점',
#   '영업중',
#   '서울특별시 서초구 남부순환로 2335 (방배동, 옥스포드빌딩) .',
#   '02-581-4858'],
#  ['경기 성남시',
#   '분당서현점',
#   '영업중',
#   '경기도 성남시 분당구 황새울로 315, 1층 104 (서현동, 대현빌딩) .',
#   '031-781-6254'],
#  ['경기 부천시 원미구',
#   '부천중동점',
#   '영업중',
#   '경기도 부천시 원미구 소향로 203, B동 109-110호  중동 1152-3 매트로펠리스 B동1층',
#   '032-325-6766'],
#  ['서울 성북구', '돈암점', '영업중', '서울특별시 성북구 동소문로20가길 28 (동선동1가) .', '02-924-6114'],
#  ['서울 광진구',
#   '테크노마트점',
#   '영업중',
#   '서울특별시 광진구 광나루로56길 85 (구의동, 테크노-마트21) 9층',
#   '02-3424-8484'],
#  ['경기 군포시',
#   '산본점',
#   '영업중',
#   '경기도 군포시 번영로 505 1층 (산본동, 대우디오플러스)  ',
#   '031-392-5999'],
#  ['광주 동구', '광주충장로점', '영업중', '광주광역시 동구 충장로안길 43 .', '062-223-0688'],
#  ['서울 송파구',
#   '교통회관점',
#   '영업중',
#   '서울특별시 송파구 올림픽로 319 (신천동, 새마을 교통회관) 1층',
#   '02-3431-1120'],
#  ['서울 강남구',
#   '역삼스타점',
#   '영업중',
#   '서울특별시 강남구 테헤란로26길 12, 1층 (역삼동 736-56) 할리스',
#   '02-501-4142'],
#  ['부산 남구',
#   '부산경성대2호점',
#   '영업중',
#   '부산광역시 남구 수영로 306, 3층 (대연동 72-1) 할리스',
#   '051-611-3021'],
#  ['서울 강서구', '김포공항점', '영업중', '서울특별시 강서구 하늘길 112 김포공항 국내선청사 1층', '02-2064-0312'],
#  ['서울 영등포구', '여의도하나투자점', '영업중', '서울특별시 영등포구  의사당대로 82 1층 할리스', '02-761-7231'],
#  ['서울 은평구', '구산역점', '영업중', '서울특별시 은평구 연서로 135 (구산동 1-7) 할리스 ', '02-351-3094'],
#  ['부산 해운대구',
#   '부산송정점',
#   '영업중',
#   '부산광역시 해운대구 송정광어골로 77 (송정동 443-5) 할리스',
#   '051-701-5591'],
#  ['서울 광진구',
#   '광나루역점',
#   '영업중',
#   '서울특별시 광진구 천호대로 808, 광장현대홈타운 제1202동 상가 1층 (광장동 580) 할리스',
#   '02-444-0542'],
#  ['부산 수영구',
#   '부산광안대교점',
#   '영업중',
#   '부산광역시 수영구 광안해변로 217, 호메르스관광호텔 1층 (광안동 93-1) 할리스',
#   '051-754-9985'],
#  ['광주 북구', '광주전남대점', '영업중', '광주광역시 북구 우치로 90(용봉동) 할리스', '062-251-1966'],
#  ['대전 유성구', '대전도안DT점', '영업중', '대전광역시 유성구 도안동로 488,1-3층 할리스', '042-824-4931'],
#  ['서울 강남구',
#   '세로수길점',
#   '영업중',
#   '서울특별시 강남구 강남대로152길 41 (신사동 536-6) 할리스',
#   '02-511-1473'],
#  ['서울 양천구',
#   '목동점',
#   '영업중',
#   '서울특별시 양천구 목동서로 159-1 CBS 1,2층 CBS 1,2층 할리스',
#   '02-2062-1063'],
#  ['광주 서구', '광주아울렛점', '영업중', '광주광역시 서구  상무대로 633', '062-385-5122'],
#  ['울산 남구',
#   '울산디자인거리점',
#   '영업중',
#   '울산광역시 남구 돋질로302번길 38 (삼산동 1575-22) 할리스',
#   '052-256-0566'],
#  ['경기 성남시 분당구',
#   '분당율동공원점',
#   '영업중',
#   '경기도 성남시 분당구 문정로 140 (율동) 할리스',
#   '031-701-0680'],
#  ['서울 영등포구', '당산역점', '영업중', '서울특별시 영등포구 당산로 219 ', '02-2631-3446'],
#  ['서울 중구',
#   '무교점',
#   '영업중',
#   '서울특별시 중구   무교로 28, 시그너스빌딩 1층 (무교동 7번지)',
#   '02-318-0988'],
#  ['경기 수원시 권선구',
#   '수원권선행복점',
#   '영업중',
#   '경기도 수원시 권선구  권광로 119 (권선동) 1층 할리스',
#   '031-221-7895'],
#  ['부산 동래구',
#   '부산동래역점',
#   '영업중',
#   '부산광역시 동래구 삼성대길 34-25, 1~3층 (명륜동 502-4) 할리스',
#   '051-552-2990'],
#  ['서울 은평구',
#   '연신내점',
#   '영업중',
#   '서울특별시 은평구 연서로 212, (대조동 199-28) 할리스',
#   '02-388-3977'],
#  ['서울 송파구',
#   '잠실광고회관점',
#   '영업중',
#   '서울특별시 송파구 올림픽로35길 137, 한국방송문화회관 1층 (신천동 7-11) 할리스',
#   '02-2144-0888'],
#  ['경남 창원시 성산구',
#   '창원상남점',
#   '영업중',
#   '경상남도 창원시 성산구 마디미로31번길 3 (상남동 상남동 18-9) 할리스',
#   '055-261-5955'],
#  ['서울 송파구',
#   '배명사거리점',
#   '영업중',
#   '서울특별시 송파구 백제고분로 275, 1층 (석촌동 14-7) 할리스',
#   '02-422-4915'],
#  ['서울 관악구',
#   '서울대예술문화점',
#   '영업중',
#   '서울특별시 관악구 관악로 1 서울대예술복합계연구동 1층',
#   '02-877-7186'],
#  ['서울 관악구', '낙성대역점', '영업중', '서울특별시 관악구 남부순환로 1922 ', '070-4716-0775'],
#  ['서울 노원구', '노원문화의거리점', '영업중', '서울특별시 노원구 노해로81길 22-26 할리스', '02-935-8231'],
#  ['부산 해운대구',
#   '부산해운대점',
#   '영업중',
#   '부산광역시 해운대구 해운대해변로 277, 다옴빌딩 1~2층 (중1동 1412-7) 할리스',
#   '051-746-1463'],
#  ['서울 강남구',
#   '도곡점',
#   '영업중',
#   '서울특별시 강남구 논현로28길 54, 덕원빌딩 1층 (도곡동 422-2) 할리스',
#   '02-6204-3311'],
#  ['서울 종로구', '대명거리점', '영업중', '서울특별시 종로구 대명길 6 2~4층 할리스', '02-747-0348'],
#  ['부산 남구',
#   '부산경성대점',
#   '영업중',
#   '부산광역시 남구 용소로 7, 청라빌딩 2~3층 (대연동 56-8) 할리스',
#   '051-611-6893'],
#  ['경기 성남시 분당구',
#   '분당수내엔타워점',
#   '영업중',
#   '경기도 성남시 분당구 황새울로200번길 26, 엔타워빌딩 1층 (수내동, 교보생명)',
#   '031-712-0341'],
#  ['인천 연수구',
#   '인천한옥마을점',
#   '영업중',
#   '인천광역시 연수구 테크노파크로 180, 다동 지상1층(송도동) ',
#   '032-831-0337'],
#  ['인천 남동구',
#   '인천구월로데오점',
#   '영업중',
#   '인천광역시 남동구 인하로 497-24 (구월동, 조한빌딩) 1층',
#   '032-421-0399'],
#  ['서울 강남구',
#   '강남역점',
#   '영업중',
#   '서울특별시 강남구 강남대로 402, 시계탑빌딩 B1~1층 (역삼동 820-11)  할리스',
#   '02-555-0890'],
#  ['대전 서구', '대전둔산청솔점', '영업중', '대전광역시 서구 둔산로 223 제상가 2동 할리스', '042-489-7990'],
#  ['경기 수원시 권선구',
#   '수원권선점',
#   '영업중',
#   '경기도 수원시 권선구  권선로 667 (권선동) 1층 할리스',
#   '031-302-2601'],
#  ['서울 용산구',
#   '용산더프라임점',
#   '영업중',
#   '서울특별시 용산구 원효로90길 11 더프라임타워 업무동 1층',
#   '02-6362-7990'],
#  ['경남 창원시 마산회원구',
#   '마산터미널점',
#   '영업중',
#   '경상남도 창원시 마산회원구 합성옛길 159, 마산시외버스터미널 1층(합성동 267) 할리스',
#   '055-251-5698'],
#  ['서울 종로구',
#   '세종로점',
#   '영업중',
#   '서울특별시 종로구 세종대로 161, 2~3층 (세종로 200) 할리스',
#   '02-720-5582'],
#  ['서울 광진구',
#   '광장점',
#   '영업중',
#   '서울특별시 광진구 광나루로620, 이진빌딩 1층 (구의동 199-2) 할리스',
#   '070-4706-0293'],
#  ['경기 수원시 팔달구', '수원역점', '영업중', '경기도 수원시 팔달구 향교로 6 (매산로1가)', '031-257-3313'],
#  ['서울 종로구',
#   '종로코리안리빌딩점',
#   '영업중',
#   '서울특별시 종로구 종로5길 68 코리안리빌딩 1층 할리스',
#   '070-4733-4828'],
#  ['경기 성남시 분당구',
#   '성남터미널점',
#   '영업중',
#   '경기도 성남시 분당구  성남대로925번길 16 (야탑동, 분당종합터미널) 1층 할리스 ',
#   '031-725-1004'],
#  ['서울 마포구', '합정역점', '영업중', '서울특별시 마포구 양화로 36 (합정동 374-1) 할리스', '02-6204-1234'],
#  ['부산 해운대구',
#   '부산달맞이점',
#   '영업중',
#   '부산광역시 해운대구 달맞이길 199, 2~3층 (중동 1488-14) 할리스',
#   '051-731-3410'],
#  ['경기 성남시 수정구',
#   '신흥역점',
#   '영업중',
#   '경기도 성남시 수정구 산성대로 265 (신흥동) 2층 할리스',
#   '031-626-6140'],
#  ['서울 관악구', '신림점', '영업중', '서울특별시 관악구 신림로 353-1', '02-877-0019'],
#  ['서울 중구',
#   '태평로점',
#   '영업중',
#   '서울특별시 중구 세종대로 64, 해남빌딩 1층 (태평로2가 70-5) 할리스',
#   '02-755-7795'],
#  ['부산 부산진구',
#   '부산서면본점',
#   '영업중',
#   '부산광역시 부산진구 동천로 73, DS타워 1~2층 (부전동 부전동 169-1) 할리스',
#   '051-819-9117'],
#  ['서울 서대문구',
#   '신촌점',
#   '영업중',
#   '서울특별시 서대문구 연세로 34 (창천동 31-12)  할리스',
#   '02-393-2004']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(result, columns = ['지역','매장명','현황','주소','전화번호'])
df.head()
# Out:
#            지역                매장명   현황  \
# 0  충남 천안시 동남구  순천향대학교 천안병원 외래센터점  영업중
# 1  충남 천안시 동남구    순천향대학교 천안병원 본관점  영업중
# 2      충남 공주시          (천)이인휴게소점  영업중
# 3      충남 공주시        (논)탄천휴게소2호점  영업중
# 4      서울 강남구           강남우리라운지점  영업중
#
#                                                 주소         전화번호
# 0  충청남도 천안시 동남구 순천향6길 31 (봉명동, 순천향대학교천안병원) 외래센터 2층            .
#        '부산 동구', '전남 목포시', '광주 서구', '경남 사천시', '강원 동해시', '경북 경산시', '강원 원주시',
#        '경북 군위군', '전북 남원시', '전남 여수시', '경기 안양시', '충북 단양군', '광주 동구',
#        '전북 고창군', '경남 거창군', '충북 진천군', '강원 강릉시', '경북 문경시', '광주 남구',
#        '경기 성남시', '부산 남구', '경기 수원시 팔달구', '경기 성남시 수정구'], dtype=object)

# %%
df['지역2'] = df['지역'].apply(lambda x : x.split()[0])

# %%
grouped = df.groupby(['지역2'])

# %%
for key, data in grouped:
    print(key)
    print(data)
    print('---------------')
# Out:
# 강원
#          지역         매장명   현황                                   주소  \
# 19   강원 홍천군  (상)홍천휴게소R점  영업중            강원도 홍천군 화촌면 서울양양고속도로 83 .
# 99   강원 속초시     속초센텀마크점  영업중         강원도 속초시 중앙로121번길 28 (금호동) 1층
# 112  강원 속초시     속초영랑해변점  영업중  강원도 속초시 영랑해안길 205 (영랑동 148-172) 할리스
# 137  강원 속초시      속초엑스포점  영업중          강원도 속초시 청초호반로 75 (조양동) 1~3층
# 147  강원 양양군     낙산해수욕장점  영업중                강원도 양양군 강현면 해맞이길 18 .
# 155  강원 인제군         인제점  영업중                강원도 인제군 인제읍 인제로 198 .
# 299  강원 홍천군   (하)홍천휴게소점  영업중            강원도 홍천군 화촌면 서울양양고속도로 84 .
# 337  강원 홍천군         홍천점  영업중                 강원도 홍천군 홍천읍 꽃뫼로 98 .
# 371  강원 동해시     동해촛대바위점  영업중         강원도 동해시 촛대바위길 16 (추암동 1-6) .
# 378  강원 원주시     원주단계택지점  영업중                 강원도 원주시 장미공원길 27-9 .
# 404  강원 동해시       동해묵호점  영업중         강원도 동해시 해안로 368 (평릉동, 시드니) .
# 426  강원 원주시   (춘)치악휴게소점  영업중            강원도 원주시 신림면 다리실2길 32 0000
# 434  강원 원주시       원주중앙점  영업중                강원도 원주시 중평길 4, 2~4층 .
# 438  강원 강릉시     강릉항마리나점  영업중              강원도 강릉시 창해로14번길 51-20 .
# 442  강원 원주시   (부)치악휴게소점  영업중                강원도 원주시 신림면 치악로 416 0
#
#               전화번호 지역2
# 19   010-4668-2505  강원
# 99    033-638-8700  강원
# 112   033-637-0164  강원
# 137   033-638-2123  강원
# 147   033-673-0053  강원
# 155   033-461-7767  강원
# 299              .  강원
# 337   033-432-3368  강원
# 371   033-522-0117  강원
# 378   033-745-5007  강원
# 404   033-534-8902  강원
# 426   033-762-8129  강원
# 434   033-748-1188  강원
# 438  070-8816-6543  강원
# 442   033-762-8128  강원
# ---------------
# 경기
#               지역         매장명   현황  \
# 5         경기 수원시       수원영통점  영업중
# 6     경기 고양시 덕양구        원흥역점  영업중
# 16    경기 고양시 덕양구       고양향동점  영업중
# 22   경기 고양시 일산동구      성남모란역점  영업중
# 27   경기 고양시 일산동구  롯데시네마라페스타점  영업중
# ..           ...         ...  ...
# 501   경기 성남시 분당구    분당수내엔타워점  영업중
# 506   경기 수원시 권선구       수원권선점  영업중
# 511   경기 수원시 팔달구        수원역점  영업중
# 513   경기 성남시 분당구      성남터미널점  영업중
# 336   042-389-2831  대전
# 396   042-826-6080  대전
# 409   042-714-5808  대전
# 418   042-528-2155  대전
# 422   042-542-8080  대전
# 480   042-824-4931  대전
# 505   042-489-7990  대전
# ---------------
# 부산
#           지역          매장명   현황  \
# 14     부산 북구        부산화명점  영업중
# 20   부산 부산진구      부산시민공원점  영업중
# 28    부산 기장군     부산일광신도시점  영업중
# 33    부산 사하구  부산아트몰링영풍문고점  영업중
# 44   부산 부산진구       부산동의대점  영업중
# 48    부산 동래구      부산명륜자이점  영업중
# 59     부산 서구       부산서구청점  영업중
# 78    부산 강서구       가덕휴게소점  영업중
# 120   부산 수영구       부산광안리점  영업중
# 121   부산 사상구      부산사상광장점  영업중
# 133  부산 해운대구      부산센텀시티점  영업중
# 227   부산 금정구     부산금강식물원점  영업중
# 238    부산 중구       부산중앙역점  영업중
# 242   부산 사상구      부산백양대로점  영업중
# 253   부산 동래구       부산명륜역점  영업중
# 260    부산 북구        부산덕천점  영업중
# 296   부산 연제구        부산연산점  영업중
# 310   부산 수영구      부산광안해변점  영업중
# 326   부산 기장군    (상)장안휴게소점  영업중
# 327   부산 기장군    (하)장안휴게소점  영업중
# 331    부산 중구    부산BIFF광장점  영업중
# 332    부산 동구        부산역사점  영업중
# 350    부산 동구      동부산우체국점  영업중
# 358   부산 강서구     명지국제신도시점  영업중
# 376    부산 서구        부산송도점  영업중
# 440   부산 수영구     부산수영로터리점  영업중
# 472    부산 남구     부산경성대2호점  영업중
# 476  부산 해운대구        부산송정점  영업중
# 478   부산 수영구      부산광안대교점  영업중
# 489   부산 동래구       부산동래역점  영업중
# 497  부산 해운대구       부산해운대점  영업중
# 500    부산 남구       부산경성대점  영업중
# 515  부산 해운대구       부산달맞이점  영업중
# 519  부산 부산진구       부산서면본점  영업중
#
#                                                     주소           전화번호 지역2
# 14   부산광역시 북구 금곡대로285번길 13 (화명동, 스포렉스) 스포렉스 106호,10...  070-8884-1101  부산
# 20                   부산 부산진구 시민공원로 73, 푸드코트피크닉 범전동 200              .  부산
# 28                 부산광역시 기장군 일광읍 해빛6로 43-20 삼성리 840-12              .  부산
# 33                 부산광역시 사하구 낙동남로 1413 (하단동, 아트몰링) 13층   051-201-0621  부산
# 44                       부산광역시 부산진구 엄광로 176 가야동, 동의대학교   051-893-6679  부산
# 48                         부산광역시 동래구 동래로 77 (명륜동) 1,2층   051-554-1001  부산
# 59            부산광역시 서구 보수대로 9 (충무동1가 3-1) 바른빌딩 1층 104호  070-4647-1455  부산
# 78                         부산광역시 강서구 거가대로 2571 (천성동) .   051-715-2200  부산
# 120           부산광역시 수영구 광안해변로 175 (광안동, 광안에이파크오션) 1~2층   051-757-9433  부산
# 121            부산광역시 사상구 광장로 22 (괘법동) 2층 사상구 괘법동 565-2   051-322-4117  부산
# 133                부산광역시 해운대구 센텀2로 24 (우동, 센텀다이아몬드) 1층   051-755-9100  부산
# 227  부산광역시 금정구 금샘로 22 (장전동) 1,2층 금정구 장전동 521-68외1필지...   051-517-1110  부산
# 238                         부산광역시 중구 대청로 148 (중앙동2가) .   051-253-8883  부산
# 242              부산광역시 사상구 백양대로 621, 2~4층(괘법동 141) 할리스   051-311-5399  부산
# 253                          부산광역시 동래구 온천장로 5 (온천동) 1층   051-557-7811  부산
# 260            부산광역시 북구 덕천1길 21, 1~2층 (덕천동 400-14) 할리스   051-342-8835  부산
# 296                          부산광역시 연제구 반송로 89 (연산동) 1층   051-989-3296  부산
# 310                    부산광역시 수영구 광안해변로 251 (민락동) 178-5   051-752-4551  부산
# 326                          부산광역시 기장군 장안읍 동해고속도로 26 .   051-727-3714  부산
# 327                부산광역시 기장군 장안읍 동해고속도로 25 (장안휴게소하행) .   051-727-3647  부산
# 331                             부산 중구 비프광장로 31-1, 1층 .   051-242-6552  부산
# 332  부산광역시 동구 중앙대로 206 (초량동, 한국철도공사부산지역본부) 2충 초량동 1...   051-441-0918  부산
# 350                             부산광역시 동구 조방로 15, 1층  .   051-631-3193  부산
# 358                   부산광역시 강서구 명지국제11로 57  명지동 3334-4   051-271-5600  부산
# 376                              부산광역시 서구 송도해변로 61-1 .   051-255-6100  부산
# 440             부산광역시 수영구 수영로 710-1, 프라임메디컬빌딩 2층 201 .  070-4239-7541  부산
# 472                부산광역시 남구 수영로 306, 3층 (대연동 72-1) 할리스   051-611-3021  부산
# 476               부산광역시 해운대구 송정광어골로 77 (송정동 443-5) 할리스   051-701-5591  부산
# 478    부산광역시 수영구 광안해변로 217, 호메르스관광호텔 1층 (광안동 93-1) 할리스   051-754-9985  부산
# 489         부산광역시 동래구 삼성대길 34-25, 1~3층 (명륜동 502-4) 할리스   051-552-2990  부산
# 497  부산광역시 해운대구 해운대해변로 277, 다옴빌딩 1~2층 (중1동 1412-7) 할리스   051-746-1463  부산
# 500           부산광역시 남구 용소로 7, 청라빌딩 2~3층 (대연동 56-8) 할리스   051-611-6893  부산
# 515         부산광역시 해운대구 달맞이길 199, 2~3층 (중동 1488-14) 할리스   051-731-3410  부산
# 519   부산광역시 부산진구 동천로 73, DS타워 1~2층 (부전동 부전동 169-1) 할리스   051-819-9117  부산
# ---------------
# 서울
#           지역        매장명   현황                                          주소  \
# 4     서울 강남구   강남우리라운지점  영업중       서울특별시 강남구 테헤란로 301 역삼동 701-02 삼정빌딩 1층
# 7     서울 용산구      이태원역점  영업중                    서울특별시 용산구 이태원로 180 2층~3층
# 8     서울 양천구      오목교역점  영업중             서울특별시 양천구 오목로 344 (목동, 청학빌딩) 1층
# 11    서울 금천구     시흥사거리점  영업중                서울특별시 금천구 시흥대로 225 시흥동 994-9
# 15    서울 서초구       방배역점  영업중          서울특별시 서초구 방배로 107 (방배동, 디엠타워3관) 1층
# ..       ...        ...  ...                                         ...
# 512   서울 종로구  종로코리안리빌딩점  영업중             서울특별시 종로구 종로5길 68 코리안리빌딩 1층 할리스
# 514   서울 마포구       합정역점  영업중            서울특별시 마포구 양화로 36 (합정동 374-1) 할리스
# 517   서울 관악구        신림점  영업중                         서울특별시 관악구 신림로 353-1
FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key, data in grouped:

# %%
df2 = grouped.count()
df2 = df2.loc[:,['지역']]

# %%
df2.reset_index()
# Out:
#    지역2   지역
# 0   강원   15
# 1   경기  121
# 2   경남   25
# 3   경북   16
# 4   광주   15
# 5   대구   26
# 6   대전   20
# 7   부산   34
# 8   서울  128
# 9   세종    4
# 10  울산   16
# 11  인천   19
# 12  전남   11
# 13  전북   29
# 14  제주    2
# 15  충남   21
# 16  충북   19

# %%
df2.sort_values
# Out:
# <bound method DataFrame.sort_values of       지역
# 지역2
# 강원    15
# 경기   121
# 경남    25
# 경북    16
# 광주    15
# 대구    26
# 대전    20
# 부산    34
# 서울   128
# 세종     4
# 울산    16
# 인천    19
# 전남    11
# 전북    29
# 제주     2
# 충남    21
# 충북    19>

# %%
df2.sort_values(by='지역', ascending=False, inplace=True)

# %%
df2.head()
# Out:
#       지역
# 지역2
# 서울   128
# 경기   121
# 부산    34
# 전북    29
# 대구    26

# %% [markdown]
# # 동적 크롤링

# %%
conda install selenium
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\miniconda3\envs\py
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.01.10 |       haa95532_0         121 KB
#     selenium-3.141.0           |py310h2bbff1b_1000         817 KB
#     ------------------------------------------------------------
#                                            Total:         938 KB
#
# The following NEW packages will be INSTALLED:
#
#   selenium           pkgs/main/win-64::selenium-3.141.0-py310h2bbff1b_1000
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.10.11-haa95532_0 --> 2023.01.10-haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# selenium-3.141.0     | 817 KB    |            |   0%
#
# ca-certificates-2023 | 121 KB    |            |   0%
# selenium-3.141.0     | 817 KB    | ##9        |  29%
#
# ca-certificates-2023 | 121 KB    | ########## | 100%
#
# ca-certificates-2023 | 121 KB    | ########## | 100%
# selenium-3.141.0     | 817 KB    | ########## | 100%
# selenium-3.141.0     | 817 KB    | ########## | 100%
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.1.0

# %%
conda install conda=23.1.0
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\user\miniconda3\envs\py
#
#   added / updated specs:
#     - conda=23.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.1.0               |  py310haa95532_0         957 KB
#     conda-package-handling-2.0.2|  py310haa95532_0         286 KB
#     conda-package-streaming-0.7.0|  py310haa95532_0          27 KB
#     zstandard-0.18.0           |  py310h2bbff1b_0         310 KB
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda              pkgs/main/win-64::conda-23.1.0-py310haa95532_0
#   conda-package-han~ pkgs/main/win-64::conda-package-handling-2.0.2-py310haa95532_0
#   conda-package-str~ pkgs/main/win-64::conda-package-streaming-0.7.0-py310haa95532_0
#   menuinst           pkgs/main/win-64::menuinst-1.4.19-py310h59b6b97_0
#   pluggy             pkgs/main/win-64::pluggy-1.0.0-py310haa95532_1
#   pycosat            pkgs/main/win-64::pycosat-0.6.4-py310h2bbff1b_0
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py310h2bbff1b_0
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py310h2bbff1b_1
#   toolz              pkgs/main/win-64::toolz-0.12.0-py310haa95532_0
#   tqdm               pkgs/main/win-64::tqdm-4.64.1-py310haa95532_0
#   zstandard          pkgs/main/win-64::zstandard-0.18.0-py310h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# zstandard-0.18.0     | 310 KB    |            |   0%
#
# conda-23.1.0         | 957 KB    |            |   0%
#
#
# conda-package-stream | 27 KB     |            |   0%
#
#
#
# conda-package-handli | 286 KB    |            |   0%
#
#
# conda-package-stream | 27 KB     | #####8     |  58%
#
#
#
# conda-package-handli | 286 KB    | 5          |   6%
# zstandard-0.18.0     | 310 KB    | 5          |   5%
#
# conda-23.1.0         | 957 KB    | 1          |   2%
#
#
# conda-package-stream | 27 KB     | ########## | 100%
#
#
# conda-package-stream | 27 KB     | ########## | 100%
#
# conda-23.1.0         | 957 KB    | #####      |  50%
#
#
#
# conda-package-handli | 286 KB    | ########## | 100%
#
#
#
# conda-package-handli | 286 KB    | ########## | 100%
# zstandard-0.18.0     | 310 KB    | ########## | 100%
# zstandard-0.18.0     | 310 KB    | ########## | 100%
#
# conda-23.1.0         | 957 KB    | ########## | 100%
#
# conda-23.1.0         | 957 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.1.0

# %% [markdown]
# # webDriver download

# %%
webdriver_path = 'C:/Users/user/Downloads/chromedriver_win32/chromedriver.exe'

# %%
from selenium import webdriver

# %%
wd = webdriver.Chrome(webdriver_path)
wd.get('https://www.coffeebeankorea.com/store/store.asp')

# %%
wd.execute_script("storePop2('52')")

# %%
html = wd.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
tables = soup.select('#matizCoverLayer0Content > div > div > div.store_txt > table > tbody')
tables
# Out:
# [<tbody> <tr> <th>영업시간</th> <td>평일 07:00~21:00 | 토/일/공휴일 07:00~21:00</td> </tr> <tr> <th>주차</th> <td>1시간 무료주차 가능 / 1시간 이후 시간당 3,000원 금액발생 (건물1층 기계식 주차장) 외제차,RV차량 주차 불가 (평일 ~오후 10시까지 / 주말 ~오후 9시까지 이용가능)</td> </tr> <tr> <th>주소</th> <td>서울시 서초구 서초중앙로 43 로얄타워1층  <!--span class="lot">(서울시 서초구 서초중앙로 43 로얄타워1층)</span--></td> </tr> <tr> <th>전화번호</th> <td>02-523-3671</td> </tr> </tbody>,
#  <tbody> </tbody>]

# %%
tables = soup.select('table.score_table > tbody > tr > th')
tables
# Out:
# []

# %%
columns = [i.string for i in tables]
columns
# Out:
# []

# %%
wd = webdriver.Chrome(webdriver_path)
wd.get('https://www.coffeebeankorea.com/store/store.asp')
wd.execute_script("storePop2('52')")
store = soup.select('div.store_txt > table > tbody > tr > td')
store[0].string, store[1].string, store[2].string, store[3].string
# Out:
# ('평일 07:00~21:00 | 토/일/공휴일 07:00~21:00',
#  '1시간 무료주차 가능 / 1시간 이후 시간당 3,000원 금액발생 (건물1층 기계식 주차장) 외제차,RV차량 주차 불가 (평일 ~오후 10시까지 / 주말 ~오후 9시까지 이용가능)',
#  None,
#  '02-523-3671')
